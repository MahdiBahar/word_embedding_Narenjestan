# %%
from hazm import *

# %%
# text = "در تبادل مانده انتقالی کاربر پیغام خطای کد ملی وارد شده مرتبط با این عملیات نمی‌باشد دریافت می‌گردد در تمامی فعالیتهایی که منجر به ایجاد مانده انتقالی می‌شوند شناسه مشتری کدملی/ شناسه ملی در فرم پولشویی از اطلاعات قبلی بازیابی نشده و کاربر ملزم به درج شناسه مشتری کدملی/ شناسه ملی در فرم پولشویی برای فعالیت بعدی می‌باشد جهت استعلام کدملی مربوط به مانده ایجادی می‌بایست از طریق سامانه بک آفیس پشتیبانی فنی بازیابی اطلاعات شناسه مشتری تسک انتقالی اقدام گردد"
text = "در تبادل مانده های انتقالی کاربر پیغام خطای کد ملیتان وارد شده "
# text2 = " درخواست خدمت اعتباری تغییر ضامن پیغام خطای مصوبه فوق فاقد وثیقه ضامن پذیر است دریافت می‌گردد چاپ مجدد پیشنهاد بررسی گردد در صورتی که تیک قرارداد لازم اجرا ثبت شده باشد می‌بایست ضامن تعریف گردد."
# text3 = " در سامانه بایگانی الکترونیک سند تایید سند در شعبه تعداد سند را اشتباه نمایش میدهد."
# text4 = " در سامانه وندیا شماره شناسه وندیا به صورت N / A نمایش داده می‌شود."

# %%
# normalizer.normalize('اصلاح نويسه ها و استفاده از نیم‌فاصله پردازش را آسان مي كند')
# normalizer.normalize(text2)
# 'اصلاح نویسه‌ها و استفاده از نیم‌فاصله پردازش را آسان می‌کند'

# %%
# sent_tokenize('ما هم برای وصل کردن آمدیم! ولی برای پردازش، جدا بهتر نیست؟')
# ['ما هم برای وصل کردن آمدیم!', 'ولی برای پردازش، جدا بهتر نیست؟']

# %%
# word_tokenize('ولی برای پردازش، جدا بهتر نیست؟')
# ['ولی', 'برای', 'پردازش', '،', 'جدا', 'بهتر', 'نیست', '؟']
# word_tokenize(text2)

# %%
text = " در تبادل مانده های انتقالی کاربر پیغام خطای کد ملیتان وارد شده را دریافت میکند و بعد از آن میخواهیم ببینیم مساله حل شده یا نشده است اتمام "

# %%
from hazm import POSTagger, word_tokenize

# relative to your project root:
tagger = POSTagger(model="resources/pos_tagger.model")
# print(tagger.tag(word_tokenize("ما بسیار کتاب می‌خوانیم")))
# text = "در تبادل مانده انتقالی کاربر پیغام خطای کد ملی وارد شده مرتبط با این عملیات نمی‌باشد دریافت می‌گردد در تمامی فعالیتهایی که منجر به ایجاد مانده انتقالی می‌شوند شناسه مشتری کدملی/ شناسه ملی در فرم پولشویی از اطلاعات قبلی بازیابی نشده و کاربر ملزم به درج شناسه مشتری کدملی/ شناسه ملی در فرم پولشویی برای فعالیت بعدی می‌باشد جهت استعلام کدملی مربوط به مانده ایجادی می‌بایست از طریق سامانه بک آفیس پشتیبانی فنی بازیابی اطلاعات شناسه مشتری تسک انتقالی اقدام گردد"

# %%
# text = "در تبادل مانده انتقالی کاربر پیغام خطای کد ملی واردشده مرتبط با این عملیات نمی‌باشد دریافت می‌گردد در تمامی فعالیتهایی که منجر به ایجاد مانده انتقالی می‌شوند شناسه مشتری کدملی/ شناسه ملی در فرم پولشویی از اطلاعات قبلی بازیابی نشده و کاربر ملزم به درج شناسه مشتری کدملی/ شناسه ملی در فرم پولشویی برای فعالیت بعدی می‌باشد جهت استعلام کدملی مربوط به مانده ایجادی می‌بایست از طریق سامانه بک آفیس پشتیبانی فنی بازیابی اطلاعات شناسه مشتری تسک انتقالی اقدام گردد"

print(tagger.tag(word_tokenize(text)))
# Out:
# [('در', 'ADP'), ('تبادل', 'NOUN,EZ'), ('مانده', 'NOUN,EZ'), ('های', 'NOUN,EZ'), ('انتقالی', 'ADJ'), ('کاربر', 'NOUN'), ('پیغام', 'NOUN'), ('خطای', 'NOUN,EZ'), ('کد', 'NOUN,EZ'), ('ملیتان', 'NOUN'), ('وارد', 'NOUN'), ('شده', 'VERB'), ('را', 'ADP'), ('دریافت', 'NOUN'), ('میکند', 'VERB'), ('و', 'CCONJ'), ('بعد', 'ADP'), ('از', 'ADP'), ('آن', 'PRON'), ('میخواهیم', 'VERB'), ('ببینیم', 'VERB'), ('مساله', 'NOUN'), ('حل', 'NOUN'), ('شده', 'VERB'), ('یا', 'CCONJ'), ('نشده_است', 'VERB'), ('اتمام', 'NOUN')]

# %%
# tagger.tag_sents(sentences = [['من', 'به', 'مدرسه', 'ایران', 'رفته_بودم', '.']])
tagger.tag_sents(sentences = [word_tokenize(text)])
#
# Out:
# [[('در', 'ADP'),
#   ('تبادل', 'NOUN,EZ'),
#   ('مانده', 'NOUN,EZ'),
#   ('های', 'NOUN,EZ'),
#   ('انتقالی', 'ADJ'),
#   ('کاربر', 'NOUN'),
#   ('پیغام', 'NOUN'),
#   ('خطای', 'NOUN,EZ'),
#   ('کد', 'NOUN,EZ'),
#   ('ملیتان', 'NOUN'),
#   ('وارد', 'NOUN'),
#   ('شده', 'VERB'),
#   ('را', 'ADP'),
#   ('دریافت', 'NOUN'),
#   ('میکند', 'VERB'),
#   ('و', 'CCONJ'),
#   ('بعد', 'ADP'),
#   ('از', 'ADP'),
#   ('آن', 'PRON'),
#   ('میخواهیم', 'VERB'),
#   ('ببینیم', 'VERB'),
#   ('مساله', 'NOUN'),
#   ('حل', 'NOUN'),
#   ('شده', 'VERB'),
#   ('یا', 'CCONJ'),
#   ('نشده_است', 'VERB'),
#   ('اتمام', 'NOUN')]]

# %%
word_tokenize(text)
# Out:
# ['در',
#  'تبادل',
#  'مانده',
#  'های',
#  'انتقالی',
#  'کاربر',
#  'پیغام',
#  'خطای',
#  'کد',
#  'ملیتان',
#  'وارد',
#  'شده',
#  'را',
#  'دریافت',
#  'میکند',
#  'و',
#  'بعد',
#  'از',
#  'آن',
#  'میخواهیم',
#  'ببینیم',
#  'مساله',
#  'حل',
#  'شده',
#  'یا',
#  'نشده_است',
#  'اتمام']

# %%
tagger.tag_sents(sentences = [['در',
 'تبادل',
 'مانده',
 'انتقال',
 'کاربر',
 'پیغا',
 'خطا',
 'کد',
 'مل',
 'وارد',
 'شده_اس']])
# Out:
# [[('در', 'ADP'),
#   ('تبادل', 'NOUN,EZ'),
#   ('مانده', 'NOUN,EZ'),
#   ('انتقال', 'NOUN,EZ'),
#   ('کاربر', 'NOUN'),
#   ('پیغا', 'NOUN'),
#   ('خطا', 'NOUN'),
#   ('کد', 'NOUN,EZ'),
#   ('مل', 'NOUN'),
#   ('وارد', 'NOUN'),
#   ('شده_اس', 'VERB')]]

# %%
tagger.tag(word_tokenize(text))
# Out:
# [('در', 'ADP'),
#  ('تبادل', 'NOUN,EZ'),
#  ('مانده', 'NOUN,EZ'),
#  ('های', 'NOUN,EZ'),
#  ('انتقالی', 'ADJ'),
#  ('کاربر', 'NOUN'),
#  ('پیغام', 'NOUN'),
#  ('خطای', 'NOUN,EZ'),
#  ('کد', 'NOUN,EZ'),
#  ('ملیتان', 'NOUN'),
#  ('وارد', 'NOUN'),
#  ('شده', 'VERB'),
#  ('را', 'ADP'),
#  ('دریافت', 'NOUN'),
#  ('میکند', 'VERB'),
#  ('و', 'CCONJ'),
#  ('بعد', 'ADP'),
#  ('از', 'ADP'),
#  ('آن', 'PRON'),
#  ('میخواهیم', 'VERB'),
#  ('ببینیم', 'VERB'),
#  ('مساله', 'NOUN'),
#  ('حل', 'NOUN'),
#  ('شده', 'VERB'),
#  ('یا', 'CCONJ'),
#  ('نشده_است', 'VERB'),
#  ('اتمام', 'NOUN')]

# %%
details_text = tagger.data_maker(tokens = [word_tokenize(text)])
details_text
# Out:
# [[{'word': 'در',
#    'is_first': True,
#    'is_last': False,
#    'prefix-1': 'د',
#    'prefix-2': 'در',
#    'prefix-3': 'در',
#    'suffix-1': 'ر',
#    'suffix-2': 'در',
#    'suffix-3': 'در',
#    'prev_word': '',
#    'two_prev_word': '',
#    'next_word': 'تبادل',
#    'two_next_word': 'مانده',
#    'is_numeric': False,
#    'prev_is_numeric': '',
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': '',
#    'next_is_punc': False},
#   {'word': 'تبادل',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ت',
#    'prefix-2': 'تب',
#    'prefix-3': 'تبا',
#    'suffix-1': 'ل',
#    'suffix-2': 'دل',
#    'suffix-3': 'ادل',
#    'prev_word': 'در',
#    'two_prev_word': 'اتمام',
#    'next_word': 'مانده',
#    'two_next_word': 'های',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'مانده',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'م',
#    'prefix-2': 'ما',
#    'prefix-3': 'مان',
#    'suffix-1': 'ه',
#    'suffix-2': 'ده',
#    'suffix-3': 'نده',
#    'prev_word': 'تبادل',
#    'two_prev_word': 'در',
#    'next_word': 'های',
#    'two_next_word': 'انتقالی',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'های',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ه',
#    'prefix-2': 'ها',
#    'prefix-3': 'های',
#    'suffix-1': 'ی',
#    'suffix-2': 'ای',
#    'suffix-3': 'های',
#    'prev_word': 'مانده',
#    'two_prev_word': 'تبادل',
#    'next_word': 'انتقالی',
#    'two_next_word': 'کاربر',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'انتقالی',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ا',
#    'prefix-2': 'ان',
#    'prefix-3': 'انت',
#    'suffix-1': 'ی',
#    'suffix-2': 'لی',
#    'suffix-3': 'الی',
#    'prev_word': 'های',
#    'two_prev_word': 'مانده',
#    'next_word': 'کاربر',
#    'two_next_word': 'پیغام',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'کاربر',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ک',
#    'prefix-2': 'کا',
#    'prefix-3': 'کار',
#    'suffix-1': 'ر',
#    'suffix-2': 'بر',
#    'suffix-3': 'ربر',
#    'prev_word': 'انتقالی',
#    'two_prev_word': 'های',
#    'next_word': 'پیغام',
#    'two_next_word': 'خطای',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'پیغام',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'پ',
#    'prefix-2': 'پی',
#    'prefix-3': 'پیغ',
#    'suffix-1': 'م',
#    'suffix-2': 'ام',
#    'suffix-3': 'غام',
#    'prev_word': 'کاربر',
#    'two_prev_word': 'انتقالی',
#    'next_word': 'خطای',
#    'two_next_word': 'کد',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'خطای',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'خ',
#    'prefix-2': 'خط',
#    'prefix-3': 'خطا',
#    'suffix-1': 'ی',
#    'suffix-2': 'ای',
#    'suffix-3': 'طای',
#    'prev_word': 'پیغام',
#    'two_prev_word': 'کاربر',
#    'next_word': 'کد',
#    'two_next_word': 'ملیتان',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'کد',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ک',
#    'prefix-2': 'کد',
#    'prefix-3': 'کد',
#    'suffix-1': 'د',
#    'suffix-2': 'کد',
#    'suffix-3': 'کد',
#    'prev_word': 'خطای',
#    'two_prev_word': 'پیغام',
#    'next_word': 'ملیتان',
#    'two_next_word': 'وارد',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'ملیتان',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'م',
#    'prefix-2': 'مل',
#    'prefix-3': 'ملی',
#    'suffix-1': 'ن',
#    'suffix-2': 'ان',
#    'suffix-3': 'تان',
#    'prev_word': 'کد',
#    'two_prev_word': 'خطای',
#    'next_word': 'وارد',
#    'two_next_word': 'شده',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'وارد',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'و',
#    'prefix-2': 'وا',
#    'prefix-3': 'وار',
#    'suffix-1': 'د',
#    'suffix-2': 'رد',
#    'suffix-3': 'ارد',
#    'prev_word': 'ملیتان',
#    'two_prev_word': 'کد',
#    'next_word': 'شده',
#    'two_next_word': 'را',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'شده',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ش',
#    'prefix-2': 'شد',
#    'prefix-3': 'شده',
#    'suffix-1': 'ه',
#    'suffix-2': 'ده',
#    'suffix-3': 'شده',
#    'prev_word': 'وارد',
#    'two_prev_word': 'ملیتان',
#    'next_word': 'را',
#    'two_next_word': 'دریافت',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'را',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ر',
#    'prefix-2': 'را',
#    'prefix-3': 'را',
#    'suffix-1': 'ا',
#    'suffix-2': 'را',
#    'suffix-3': 'را',
#    'prev_word': 'شده',
#    'two_prev_word': 'وارد',
#    'next_word': 'دریافت',
#    'two_next_word': 'میکند',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'دریافت',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'د',
#    'prefix-2': 'در',
#    'prefix-3': 'دری',
#    'suffix-1': 'ت',
#    'suffix-2': 'فت',
#    'suffix-3': 'افت',
#    'prev_word': 'را',
#    'two_prev_word': 'شده',
#    'next_word': 'میکند',
#    'two_next_word': 'و',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'میکند',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'م',
#    'prefix-2': 'می',
#    'prefix-3': 'میک',
#    'suffix-1': 'د',
#    'suffix-2': 'ند',
#    'suffix-3': 'کند',
#    'prev_word': 'دریافت',
#    'two_prev_word': 'را',
#    'next_word': 'و',
#    'two_next_word': 'بعد',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'و',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'و',
#    'prefix-2': 'و',
#    'prefix-3': 'و',
#    'suffix-1': 'و',
#    'suffix-2': 'و',
#    'suffix-3': 'و',
#    'prev_word': 'میکند',
#    'two_prev_word': 'دریافت',
#    'next_word': 'بعد',
#    'two_next_word': 'از',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'بعد',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ب',
#    'prefix-2': 'بع',
#    'prefix-3': 'بعد',
#    'suffix-1': 'د',
#    'suffix-2': 'عد',
#    'suffix-3': 'بعد',
#    'prev_word': 'و',
#    'two_prev_word': 'میکند',
#    'next_word': 'از',
#    'two_next_word': 'آن',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'از',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ا',
#    'prefix-2': 'از',
#    'prefix-3': 'از',
#    'suffix-1': 'ز',
#    'suffix-2': 'از',
#    'suffix-3': 'از',
#    'prev_word': 'بعد',
#    'two_prev_word': 'و',
#    'next_word': 'آن',
#    'two_next_word': 'میخواهیم',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'آن',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'آ',
#    'prefix-2': 'آن',
#    'prefix-3': 'آن',
#    'suffix-1': 'ن',
#    'suffix-2': 'آن',
#    'suffix-3': 'آن',
#    'prev_word': 'از',
#    'two_prev_word': 'بعد',
#    'next_word': 'میخواهیم',
#    'two_next_word': 'ببینیم',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'میخواهیم',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'م',
#    'prefix-2': 'می',
#    'prefix-3': 'میخ',
#    'suffix-1': 'م',
#    'suffix-2': 'یم',
#    'suffix-3': 'هیم',
#    'prev_word': 'آن',
#    'two_prev_word': 'از',
#    'next_word': 'ببینیم',
#    'two_next_word': 'مساله',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'ببینیم',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ب',
#    'prefix-2': 'بب',
#    'prefix-3': 'ببی',
#    'suffix-1': 'م',
#    'suffix-2': 'یم',
#    'suffix-3': 'نیم',
#    'prev_word': 'میخواهیم',
#    'two_prev_word': 'آن',
#    'next_word': 'مساله',
#    'two_next_word': 'حل',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'مساله',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'م',
#    'prefix-2': 'مس',
#    'prefix-3': 'مسا',
#    'suffix-1': 'ه',
#    'suffix-2': 'له',
#    'suffix-3': 'اله',
#    'prev_word': 'ببینیم',
#    'two_prev_word': 'میخواهیم',
#    'next_word': 'حل',
#    'two_next_word': 'شده',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'حل',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ح',
#    'prefix-2': 'حل',
#    'prefix-3': 'حل',
#    'suffix-1': 'ل',
#    'suffix-2': 'حل',
#    'suffix-3': 'حل',
#    'prev_word': 'مساله',
#    'two_prev_word': 'ببینیم',
#    'next_word': 'شده',
#    'two_next_word': 'یا',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'شده',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ش',
#    'prefix-2': 'شد',
#    'prefix-3': 'شده',
#    'suffix-1': 'ه',
#    'suffix-2': 'ده',
#    'suffix-3': 'شده',
#    'prev_word': 'حل',
#    'two_prev_word': 'مساله',
#    'next_word': 'یا',
#    'two_next_word': 'نشده_است',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'یا',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ی',
#    'prefix-2': 'یا',
#    'prefix-3': 'یا',
#    'suffix-1': 'ا',
#    'suffix-2': 'یا',
#    'suffix-3': 'یا',
#    'prev_word': 'شده',
#    'two_prev_word': 'حل',
#    'next_word': 'نشده_است',
#    'two_next_word': 'اتمام',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'نشده_است',
#    'is_first': False,
#    'is_last': False,
#    'prefix-1': 'ن',
#    'prefix-2': 'نش',
#    'prefix-3': 'نشد',
#    'suffix-1': 'ت',
#    'suffix-2': 'ست',
#    'suffix-3': 'است',
#    'prev_word': 'یا',
#    'two_prev_word': 'شده',
#    'next_word': 'اتمام',
#    'two_next_word': '',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': False,
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': False},
#   {'word': 'اتمام',
#    'is_first': False,
#    'is_last': True,
#    'prefix-1': 'ا',
#    'prefix-2': 'ات',
#    'prefix-3': 'اتم',
#    'suffix-1': 'م',
#    'suffix-2': 'ام',
#    'suffix-3': 'مام',
#    'prev_word': 'نشده_است',
#    'two_prev_word': 'یا',
#    'next_word': '',
#    'two_next_word': '',
#    'is_numeric': False,
#    'prev_is_numeric': False,
#    'next_is_numeric': '',
#    'is_punc': False,
#    'prev_is_punc': False,
#    'next_is_punc': ''}]]

# %%
next_word = details_text[0][11-1].get("next_word")
own_word = details_text[0][11-1].get("word")
print(next_word)
print(own_word)
# Out:
# شده
# وارد

# %%
details_text = tagger.data_maker(tokens = [word_tokenize(text)])

# %%
details_text[0]
# Out:
# [{'word': 'در',
#   'is_first': True,
#   'is_last': False,
#   'prefix-1': 'د',
#   'prefix-2': 'در',
#   'prefix-3': 'در',
#   'suffix-1': 'ر',
#   'suffix-2': 'در',
#   'suffix-3': 'در',
#   'prev_word': '',
#   'two_prev_word': '',
#   'next_word': 'تبادل',
#   'two_next_word': 'مانده',
#   'is_numeric': False,
#   'prev_is_numeric': '',
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': '',
#   'next_is_punc': False},
#  {'word': 'تبادل',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'ت',
#   'prefix-2': 'تب',
#   'prefix-3': 'تبا',
#   'suffix-1': 'ل',
#   'suffix-2': 'دل',
#   'suffix-3': 'ادل',
#   'prev_word': 'در',
#   'two_prev_word': 'شده',
#   'next_word': 'مانده',
#   'two_next_word': 'های',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'مانده',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'م',
#   'prefix-2': 'ما',
#   'prefix-3': 'مان',
#   'suffix-1': 'ه',
#   'suffix-2': 'ده',
#   'suffix-3': 'نده',
#   'prev_word': 'تبادل',
#   'two_prev_word': 'در',
#   'next_word': 'های',
#   'two_next_word': 'انتقالی',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'های',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'ه',
#   'prefix-2': 'ها',
#   'prefix-3': 'های',
#   'suffix-1': 'ی',
#   'suffix-2': 'ای',
#   'suffix-3': 'های',
#   'prev_word': 'مانده',
#   'two_prev_word': 'تبادل',
#   'next_word': 'انتقالی',
#   'two_next_word': 'کاربر',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'انتقالی',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'ا',
#   'prefix-2': 'ان',
#   'prefix-3': 'انت',
#   'suffix-1': 'ی',
#   'suffix-2': 'لی',
#   'suffix-3': 'الی',
#   'prev_word': 'های',
#   'two_prev_word': 'مانده',
#   'next_word': 'کاربر',
#   'two_next_word': 'پیغام',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'کاربر',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'ک',
#   'prefix-2': 'کا',
#   'prefix-3': 'کار',
#   'suffix-1': 'ر',
#   'suffix-2': 'بر',
#   'suffix-3': 'ربر',
#   'prev_word': 'انتقالی',
#   'two_prev_word': 'های',
#   'next_word': 'پیغام',
#   'two_next_word': 'خطای',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'پیغام',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'پ',
#   'prefix-2': 'پی',
#   'prefix-3': 'پیغ',
#   'suffix-1': 'م',
#   'suffix-2': 'ام',
#   'suffix-3': 'غام',
#   'prev_word': 'کاربر',
#   'two_prev_word': 'انتقالی',
#   'next_word': 'خطای',
#   'two_next_word': 'کد',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'خطای',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'خ',
#   'prefix-2': 'خط',
#   'prefix-3': 'خطا',
#   'suffix-1': 'ی',
#   'suffix-2': 'ای',
#   'suffix-3': 'طای',
#   'prev_word': 'پیغام',
#   'two_prev_word': 'کاربر',
#   'next_word': 'کد',
#   'two_next_word': 'ملیتان',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'کد',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'ک',
#   'prefix-2': 'کد',
#   'prefix-3': 'کد',
#   'suffix-1': 'د',
#   'suffix-2': 'کد',
#   'suffix-3': 'کد',
#   'prev_word': 'خطای',
#   'two_prev_word': 'پیغام',
#   'next_word': 'ملیتان',
#   'two_next_word': 'وارد',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'ملیتان',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'م',
#   'prefix-2': 'مل',
#   'prefix-3': 'ملی',
#   'suffix-1': 'ن',
#   'suffix-2': 'ان',
#   'suffix-3': 'تان',
#   'prev_word': 'کد',
#   'two_prev_word': 'خطای',
#   'next_word': 'وارد',
#   'two_next_word': 'شده',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'وارد',
#   'is_first': False,
#   'is_last': False,
#   'prefix-1': 'و',
#   'prefix-2': 'وا',
#   'prefix-3': 'وار',
#   'suffix-1': 'د',
#   'suffix-2': 'رد',
#   'suffix-3': 'ارد',
#   'prev_word': 'ملیتان',
#   'two_prev_word': 'کد',
#   'next_word': 'شده',
#   'two_next_word': '',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': False,
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': False},
#  {'word': 'شده',
#   'is_first': False,
#   'is_last': True,
#   'prefix-1': 'ش',
#   'prefix-2': 'شد',
#   'prefix-3': 'شده',
#   'suffix-1': 'ه',
#   'suffix-2': 'ده',
#   'suffix-3': 'شده',
#   'prev_word': 'وارد',
#   'two_prev_word': 'ملیتان',
#   'next_word': '',
#   'two_next_word': '',
#   'is_numeric': False,
#   'prev_is_numeric': False,
#   'next_is_numeric': '',
#   'is_punc': False,
#   'prev_is_punc': False,
#   'next_is_punc': ''}]

# %% [markdown]
# # Test parsivar for pos tagging

# %%
from parsivar import POSTagger

my_tagger = POSTagger(
    tagging_model="stanford",
    stanford_postagger_model=(
        "/home/mahdi/word_embedding_Narenjestan/"
        "resources/stanford-tagger-4.2.0/stanford-postagger-full-2020-11-17/models/"
        "farsi.tagger"
    ),
    jar_tagger_path=(
        "/home/mahdi/word_embedding_Narenjestan/"
        "resources/stanford-tagger-4.2.0/stanford-postagger-full-2020-11-17/stanford-postagger.jar"
    ),
    jdk_variable_path="/usr/lib/jvm/java-11-openjdk-amd64"
)

text = "این سمینار تا 13 شهریور ادامه می‌یابد ."
tags = my_tagger.parse(my_tokenizer.tokenize_words(text))
print(tags)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from parsivar import POSTagger
# ----> 3 my_tagger = POSTagger(
#       4     tagging_model="stanford",
#       5     stanford_postagger_model=(
#       6         "/home/mahdi/word_embedding_Narenjestan/"
#       7         "resources/stanford-tagger-4.2.0/stanford-postagger-full-2020-11-17/models/"
#       8         "farsi.tagger"
#       9     ),
#      10     jar_tagger_path=(
#      11         "/home/mahdi/word_embedding_Narenjestan/"
#      12         "resources/stanford-tagger-4.2.0/stanford-postagger-full-2020-11-17/stanford-postagger.jar"
#      13     ),
#      14     jdk_variable_path="/usr/lib/jvm/java-11-openjdk-amd64"
#      15 )
#      17 text = "این سمینار تا 13 شهریور ادامه می‌یابد ."
#      18 tags = my_tagger.parse(my_tokenizer.tokenize_words(text))
#
# File ~/word_embedding_Narenjestan/venv11-hazm/lib/python3.11/site-packages/parsivar/postagger.py:40, in POSTagger.__init__(self, stanford_postagger_model, wapiti_postagger_model, jar_tagger_path, jdk_variable_path, tagging_model)
#      37     java_path = jdk_variable_path
#      38     os.environ['JAVAHOME'] = java_path
# ---> 40     self.tagger = StanfordPOSTagger(model_filename=self.stanford_postagger_model,
#      41                                     path_to_jar=self.jar_tagger_path,
#      42                                     encoding='utf-8',
#      43                                     java_options='-mx5000m')
#      44 elif self.tagging_model == "wapiti":
#      45     from wapiti import Model
#
# File ~/word_embedding_Narenjestan/venv11-hazm/lib/python3.11/site-packages/nltk/tag/stanford.py:159, in StanfordPOSTagger.__init__(self, *args, **kwargs)
#     158 def __init__(self, *args, **kwargs):
# --> 159     super().__init__(*args, **kwargs)
#
# File ~/word_embedding_Narenjestan/venv11-hazm/lib/python3.11/site-packages/nltk/tag/stanford.py:74, in StanfordTagger.__init__(self, model_filename, path_to_jar, encoding, verbose, java_options)
#      65     warnings.warn(
#      66         "The StanfordTagger class is not meant to be "
#      67         "instantiated directly. Did you mean "
#      68         "StanfordPOSTagger or StanfordNERTagger?"
#      69     )
#      70 self._stanford_jar = find_jar(
#      71     self._JAR, path_to_jar, searchpath=(), url=_stanford_url, verbose=verbose
#      72 )
# ---> 74 self._stanford_model = find_file(
#      75     model_filename, env_vars=("STANFORD_MODELS",), verbose=verbose
#      76 )
#      78 self._encoding = encoding
#      79 self.java_options = java_options
#
# File ~/word_embedding_Narenjestan/venv11-hazm/lib/python3.11/site-packages/nltk/internals.py:628, in find_file(filename, env_vars, searchpath, file_names, url, verbose)
#     625 def find_file(
#     626     filename, env_vars=(), searchpath=(), file_names=None, url=None, verbose=False
#     627 ):
# --> 628     return next(
#     629         find_file_iter(filename, env_vars, searchpath, file_names, url, verbose)
#     630     )
#
# File ~/word_embedding_Narenjestan/venv11-hazm/lib/python3.11/site-packages/nltk/internals.py:622, in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     620     msg += f"\n\n  For more information on {filename}, see:\n    <{url}>"
#     621 div = "=" * 75
# --> 622 raise LookupError(f"\n\n{div}\n{msg}\n{div}")
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the /home/mahdi/word_embedding_Narenjestan/resources/stanford-tagger-4.2.0/stanford-postagger-full-2020-11-17/models/farsi.tagger file!
# Use software specific configuration parameters or set the STANFORD_MODELS environment variable.
# ===========================================================================

# %%
from parsivar import POSTagger
my_tagger = POSTagger(tagging_model="wapiti")  # tagging_model = "wapiti" or "stanford". "wapiti" is faster than "stanford"
text_tags = my_tagger.parse(my_tokenizer.tokenize_words("این سمینار تا 13 شهریور ادامه می‌یابد ."))
print(text_tags)
# [('این', 'DET'), ('سمینار', 'N_SING'), ('تا', 'P'), ('13', 'NUM'), ('شهریور', 'N_SING'), ('ادامه', 'N_SING'), ('می\u200cیابد', 'V_PRS'), ('.', '.')]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from parsivar import POSTagger
# ----> 2 my_tagger = POSTagger(tagging_model="wapiti")  # tagging_model = "wapiti" or "stanford". "wapiti" is faster than "stanford"
#       3 text_tags = my_tagger.parse(my_tokenizer.tokenize_words("این سمینار تا 13 شهریور ادامه می‌یابد ."))
#       4 print(text_tags)
#
# File ~/word_embedding_Narenjestan/venv11-hazm/lib/python3.11/site-packages/parsivar/postagger.py:45, in POSTagger.__init__(self, stanford_postagger_model, wapiti_postagger_model, jar_tagger_path, jdk_variable_path, tagging_model)
#      40     self.tagger = StanfordPOSTagger(model_filename=self.stanford_postagger_model,
#      41                                     path_to_jar=self.jar_tagger_path,
#      42                                     encoding='utf-8',
#      43                                     java_options='-mx5000m')
#      44 elif self.tagging_model == "wapiti":
# ---> 45     from wapiti import Model
#      46     self.tagger = Model(model=self.wapiti_postagger_model)
#
# ModuleNotFoundError: No module named 'wapiti'
