# %%
import stanza
import os
import csv
import pandas as pd

# %%
# Download and initialize Stanza pipeline for Persian
print("Initializing Persian NLP pipeline...")
stanza.download('fa', verbose=False)
nlp = stanza.Pipeline(lang='fa', processors='tokenize,pos', verbose=False)

# POS tag translations to Persian
pos_translations = {
    'NOUN': 'اسم',
    'VERB': 'فعل', 
    'ADJ': 'صفت',
    'ADV': 'قید',
    'PRON': 'ضمیر',
    'DET': 'تعیینکننده',
    'ADP': 'حرف اضافه',
    'NUM': 'عدد',
    'CONJ': 'حرف ربط',
    'CCONJ': 'حرف ربط هماهنگکننده', 
    'SCONJ': 'حرف ربط تابعساز',
    'PART': 'ذره',
    'INTJ': 'حرف تعجب',
    'PUNCT': 'نشانه نگارشی',
    'SYM': 'نماد',
    'X': 'سایر'
}
# Out:
# Initializing Persian NLP pipeline...

# %%
def read_file(file_path):
    """Read text file with UTF-8 encoding"""
    if not os.path.exists(file_path):
        print(f"File {file_path} not found!")
        return None
    
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            print(f"Successfully read {len(content)} characters from {file_path}")
            return content
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# %%
def read_banking_terms_from_csv(csv_file):
    """Read banking terms from a CSV file"""
    banking_terms = []
    
    if not os.path.exists(csv_file):
        print(f"Banking terms file {csv_file} not found!")
        print("Please create banking_terms.csv with your banking terms.")
        return []
    
    try:
        with open(csv_file, 'r', encoding='utf-8') as f:
            reader = csv.reader(f)
            for row_num, row in enumerate(reader, 1):
                for term in row:
                    term = term.strip()
                    if term:  # Only add non-empty terms
                        banking_terms.append(term)
        
        # Remove duplicates while preserving order
        banking_terms = list(dict.fromkeys(banking_terms))
        print(f"Successfully loaded {len(banking_terms)} unique banking terms from {csv_file}")
        return banking_terms
        
    except Exception as e:
        print(f"Error reading banking terms from {csv_file}: {e}")
        return []

# %%
def split_text_by_sentences(text, max_sentences_per_chunk=30):
    """Split text into smaller chunks based on sentence count"""
    sentences = []
    current_sentence = ""
    
    for char in text:
        current_sentence += char
        if char in ['۔', '.', '!', '?', '؟', ':', '؛']:
            if current_sentence.strip():
                sentences.append(current_sentence.strip())
            current_sentence = ""
    
    if current_sentence.strip():
        sentences.append(current_sentence.strip())
    
    chunks = []
    for i in range(0, len(sentences), max_sentences_per_chunk):
        chunk = ' '.join(sentences[i:i + max_sentences_per_chunk])
        if chunk.strip():
            chunks.append(chunk)
    
    return chunks

# %%
def process_text_chunk(text_chunk, chunk_num=1, total_chunks=1):
    """Process a single chunk of text"""
    try:
        print(f"Processing chunk {chunk_num}/{total_chunks} ({len(text_chunk)} characters)")
        doc = nlp(text_chunk)
        results = []
        
        for sentence in doc.sentences:
            for word in sentence.words:
                if word.text.strip():
                    persian_pos = pos_translations.get(word.upos, word.upos)    #check
                    results.append({
                        'word': word.text,
                        'pos': word.upos,
                        'persian_pos': persian_pos
                    })
        
        print(f"Chunk {chunk_num} processed: {len(results)} words extracted")
        return results
        
    except Exception as e:
        print(f"Error processing chunk {chunk_num}: {e}")
        return []

# %%
def process_text_safely(text):
    """Process text safely by splitting into manageable chunks"""
    if not text or not text.strip():
        print("Empty text provided")
        return []
    
    print(f"Starting text processing... ({len(text)} characters)")
    
    if len(text) < 3000:
        return process_text_chunk(text)
    
    print("Large text detected, splitting into chunks...")
    text_chunks = split_text_by_sentences(text, max_sentences_per_chunk=25)
    print(f"Text split into {len(text_chunks)} chunks")
    
    all_results = []
    successful_chunks = 0
    
    for i, chunk in enumerate(text_chunks):
        chunk_results = process_text_chunk(chunk, i+1, len(text_chunks))
        if chunk_results:
            all_results.extend(chunk_results)
            successful_chunks += 1
        else:
            print(f"Warning: Chunk {i+1} failed to process")
    
    print(f"Processing completed: {successful_chunks}/{len(text_chunks)} chunks successful")
    print(f"Total words extracted: {len(all_results)}")
    return all_results

# %%
def extract_banking_entities(results, banking_terms):
    """Extract banking entities using terms from CSV file"""
    if not banking_terms:
        print("No banking terms provided for entity extraction")
        return []
    
    entities = []
    seen_entities = set()
    
    print(f"Searching for banking entities using {len(banking_terms)} terms...")
    
    for i in range(len(results) - 1):
        current_word = results[i]
        next_word = results[i + 1]
        
        if current_word['word'] in banking_terms and next_word['pos'] == 'NOUN':
            entity_text = f"{current_word['word']} {next_word['word']}"
            if entity_text not in seen_entities:
                entity = {
                    'entity': entity_text,
                    'banking_term': current_word['word']
                }
                entities.append(entity)
                seen_entities.add(entity_text)
        
        elif current_word['pos'] == 'NOUN' and next_word['word'] in banking_terms:
            entity_text = f"{current_word['word']} {next_word['word']}"
            if entity_text not in seen_entities:
                entity = {
                    'entity': entity_text,
                    'banking_term': next_word['word']
                }
                entities.append(entity)
                seen_entities.add(entity_text)
    
    print(f"Found {len(entities)} unique banking entities")
    return entities

# %%
def save_results_csv(results, output_file):
    """Save POS tagging results to CSV"""
    try:
        with open(output_file, 'w', encoding='utf-8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['کلمه', 'تگ', 'نقش'])
            for item in results:
                writer.writerow([item['word'], item['pos'], item['persian_pos']])
        print(f"POS results saved to {output_file}")
        return True
    except Exception as e:
        print(f"Error saving POS results: {e}")
        return False

# %%
def save_banking_entities_csv(entities, output_file):
    try:
        with open(output_file, 'w', encoding='utf-8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['واژه بانکی', 'ترکیب شناسایی شده'])
            for entity in entities:
                writer.writerow([entity['banking_term'], entity['entity']])
        print(f"Banking entities saved to {output_file}")
        return True
    except Exception as e:
        print(f"Error saving banking entities CSV: {e}")
        return False

def save_banking_entities_excel(entities, output_file):
    try:
        data = {
            'واژه بانکی': [entity['banking_term'] for entity in entities],
            'ترکیب شناسایی شده': [entity['entity'] for entity in entities]
        }
        df = pd.DataFrame(data)
        df.to_excel(output_file, index=False, engine='openpyxl')
        print(f"Banking entities saved to {output_file}")
        return True
    except ImportError:
        print("pandas or openpyxl not installed. Install with: pip install pandas openpyxl")
        return False
    except Exception as e:
        print(f"Error saving banking entities Excel: {e}")
        return False

# %%
def print_sample_results(results, sample_size=10):
    """Skip printing POS results - only save to files"""
    pass

def print_banking_entities(entities, max_display=20):
    """Skip printing banking entities - only save to files"""
    pass

# %%
def main():
    print("=== Persian Banking Entity Extractor ===\n")
    
    banking_terms_file = "banking_terms.csv"
    input_file = "test.txt"
    
    print("Step 1: Loading banking terms...")
    banking_terms = read_banking_terms_from_csv(banking_terms_file)
    if not banking_terms:
        print("❌ No banking terms loaded. Please create banking_terms.csv file.")
        return
    
    print("\nStep 2: Reading input text...")
    text = read_file(input_file)
    if not text:
        print("❌ Failed to read input text. Please check test.txt file.")
        return
    
    print("\nStep 3: Processing text for POS tagging...")
    results = process_text_safely(text)
    if not results:
        print("❌ Text processing failed.")
        return
    
    print("\nStep 4: Saving POS tagging results...")
    save_results_csv(results, "pos_output.csv")
    
    print("\nStep 5: Extracting banking entities...")
    banking_entities = extract_banking_entities(results, banking_terms)
    
    if not banking_entities:
        print("❌ No banking entities found in the text.")
        return
    
    print("\nStep 6: Saving banking entities...")
    save_banking_entities_csv(banking_entities, "banking_entities.csv")
    save_banking_entities_excel(banking_entities, "banking_entities.xlsx")
    
    print(f"\n=== Summary ===")
    print(f"✅ Text processed: {len(text)} characters")
    print(f"✅ Words analyzed: {len(results)}")
    print(f"✅ Banking terms loaded: {len(banking_terms)}")
    print(f"✅ Unique banking entities found: {len(banking_entities)}")
    print(f"✅ Output files created:")
    print(f"   - pos_output.csv (POS tagging results)")
    print(f"   - banking_entities.csv (Banking entities)")
    print(f"   - banking_entities.xlsx (Banking entities - Excel)")

# %%
import stanza

# build a pipeline on CPU; set use_gpu=True if you have a GPU available
nlp = stanza.Pipeline(
    lang='fa',
    processors='tokenize,mwt,pos,lemma',
    use_gpu=False
)

# %%
import stanza

# build a pipeline on CPU; set use_gpu=True if you have a GPU available
nlp = stanza.Pipeline(
    lang='fa',
    processors='tokenize,mwt,pos,lemma',
    use_gpu=False
)
# text = "کتاب‌های جذاب را من دیروز خریدم."
text = " در تبادل مانده های انتقالی کاربر پیغام خطای کد ملیتان وارد شده را دریافت میکند و بعد از آن میخواهیم ببینیم مساله حل شده یا نشده است اتمام "

doc = nlp(text)

for sentence in doc.sentences:
    for word in sentence.words:
        print(f"{word.text}\t→ {word.lemma}")
# Out:
# در	→ در
# تبادل	→ تبادل
# مانده	→ مانده
# های	→ های
# انتقالی	→ انتقالی
# کاربر	→ کاربر
# پیغام	→ پیغام
# خطای	→ خطا
# کد	→ کد
# ملیتان	→ ملیت
# وارد	→ وارد
# شده	→ شد
# را	→ را
# دریافت	→ دریافت
# میکند	→ کرد
# و	→ و
# بعد	→ بعد
# از	→ از
# آن	→ آن
# میخواهیم	→ خواست
# ببینیم	→ دید
# مساله	→ مساله
# حل	→ حل
# شده	→ شد
# یا	→ یا
# نشده	→ شد
# است	→ است
# اتمام	→ اتمام

# %%
import stanza
import os
import csv
import pandas as pd

# Download and initialize Stanza pipeline for Persian
print("Initializing Persian NLP pipeline...")
stanza.download('fa', verbose=False)
nlp = stanza.Pipeline(lang='fa', processors='tokenize,pos', verbose=False)

# POS tag translations to Persian
pos_translations = {
    'NOUN': 'اسم',
    'VERB': 'فعل', 
    'ADJ': 'صفت',
    'ADV': 'قید',
    'PRON': 'ضمیر',
    'DET': 'تعیینکننده',
    'ADP': 'حرف اضافه',
    'NUM': 'عدد',
    'CONJ': 'حرف ربط',
    'CCONJ': 'حرف ربط هماهنگکننده', 
    'SCONJ': 'حرف ربط تابعساز',
    'PART': 'ذره',
    'INTJ': 'حرف تعجب',
    'PUNCT': 'نشانه نگارشی',
    'SYM': 'نماد',
    'X': 'سایر'
}

def read_file(file_path):
    """Read text file with UTF-8 encoding"""
    if not os.path.exists(file_path):
        print(f"File {file_path} not found!")
        return None
    
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            content = f.read().strip()
            print(f"Successfully read {len(content)} characters from {file_path}")
            return content
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# def read_banking_terms_from_csv(csv_file):
#     """Read banking terms from a CSV file"""
#     banking_terms = []
    
#     if not os.path.exists(csv_file):
#         print(f"Banking terms file {csv_file} not found!")
#         print("Please create banking_terms.csv with your banking terms.")
#         return []
    
#     try:
#         with open(csv_file, 'r', encoding='utf-8') as f:
#             reader = csv.reader(f)
#             for row_num, row in enumerate(reader, 1):
#                 for term in row:
#                     term = term.strip()
#                     if term:  # Only add non-empty terms
#                         banking_terms.append(term)
        
#         # Remove duplicates while preserving order
#         banking_terms = list(dict.fromkeys(banking_terms))
#         print(f"Successfully loaded {len(banking_terms)} unique banking terms from {csv_file}")
#         return banking_terms
        
#     except Exception as e:
#         print(f"Error reading banking terms from {csv_file}: {e}")
#         return []

def split_text_by_sentences(text, max_sentences_per_chunk=10):
    """Split text into smaller chunks based on sentence count"""
    sentences = []
    current_sentence = ""
    
    # Split by Persian and English sentence markers
    for char in text:
        current_sentence += char
        if char in ['۔', '.', '!', '?', '؟', ':', '؛']:
            if current_sentence.strip():
                sentences.append(current_sentence.strip())
            current_sentence = ""
    
    # Add remaining text as last sentence if exists
    if current_sentence.strip():
        sentences.append(current_sentence.strip())
    
    # Group sentences into chunks
    chunks = []
    for i in range(0, len(sentences), max_sentences_per_chunk):
        chunk = ' '.join(sentences[i:i + max_sentences_per_chunk])
        if chunk.strip():  # Only add non-empty chunks
            chunks.append(chunk)
    
    return chunks

def split_text_by_characters(text, max_chars_per_chunk=1000):
    """Split text into chunks by character count"""
    chunks = []
    words = text.split()
    current_chunk = ""
    
    for word in words:
        # If adding this word would exceed the limit, start a new chunk
        if len(current_chunk) + len(word) + 1 > max_chars_per_chunk and current_chunk:
            chunks.append(current_chunk.strip())
            current_chunk = word
        else:
            if current_chunk:
                current_chunk += " " + word
            else:
                current_chunk = word
    
    # Add the last chunk if it has content
    if current_chunk.strip():
        chunks.append(current_chunk.strip())
    
    return chunks

def split_text_by_words(text, max_words_per_chunk=100):
    """Split text into chunks by word count"""
    words = text.split()
    chunks = []
    
    for i in range(0, len(words), max_words_per_chunk):
        chunk_words = words[i:i + max_words_per_chunk]
        chunk = ' '.join(chunk_words)
        if chunk.strip():
            chunks.append(chunk)
    
    return chunks

def process_text_chunk(text_chunk, chunk_num=1, total_chunks=1):
    """Process a single chunk of text"""
    try:
        print(f"Processing chunk {chunk_num}/{total_chunks} ({len(text_chunk)} characters)")
        doc = nlp(text_chunk)
        results = []
        
        for sentence in doc.sentences:
            for word in sentence.words:
                if word.text.strip():  # Only process non-empty words
                    persian_pos = pos_translations.get(word.upos, word.upos)
                    results.append({
                        'word': word.text,
                        'pos': word.upos,
                        'persian_pos': persian_pos
                    })
        
        print(f"Chunk {chunk_num} processed: {len(results)} words extracted")
        return results
        
    except Exception as e:
        print(f"Error processing chunk {chunk_num}: {e}")
        return []

def process_text_safely(text):
    """Process text safely by splitting into manageable chunks"""
    if not text or not text.strip():
        print("Empty text provided")
        return []
    
    print(f"Starting text processing... ({len(text)} characters)")
    
    # For very small texts, process directly
    if len(text) < 500:
        return process_text_chunk(text)
    
    # Choose splitting method based on text size
    if len(text) < 2000:
        # Small text: split by sentences (10 sentences per chunk)
        text_chunks = split_text_by_sentences(text, max_sentences_per_chunk=10)
        print(f"Small text: split into {len(text_chunks)} sentence-based chunks")
    elif len(text) < 10000:
        # Medium text: split by characters (1000 chars per chunk)
        text_chunks = split_text_by_characters(text, max_chars_per_chunk=1000)
        print(f"Medium text: split into {len(text_chunks)} character-based chunks")
    else:
        # Large text: split by words (100 words per chunk)
        text_chunks = split_text_by_words(text, max_words_per_chunk=100)
        print(f"Large text: split into {len(text_chunks)} word-based chunks")
    
    # Ensure we have multiple chunks for processing
    if len(text_chunks) == 1 and len(text) > 1000:
        # Force split large single chunks
        text_chunks = split_text_by_characters(text, max_chars_per_chunk=800)
        print(f"Forced additional splitting: {len(text_chunks)} chunks")
    
    all_results = []
    successful_chunks = 0
    failed_chunks = 0
    
    print(f"Processing {len(text_chunks)} chunks...")
    
    for i, chunk in enumerate(text_chunks):
        try:
            chunk_results = process_text_chunk(chunk, i+1, len(text_chunks))
            if chunk_results:
                all_results.extend(chunk_results)
                successful_chunks += 1
            else:
                failed_chunks += 1
                print(f"Warning: Chunk {i+1} returned no results")
        except Exception as e:
            failed_chunks += 1
            print(f"Error: Chunk {i+1} failed with error: {e}")
    
    print(f"Processing completed:")
    print(f"  ✅ Successful chunks: {successful_chunks}")
    print(f"  ❌ Failed chunks: {failed_chunks}")
    print(f"  📊 Total words extracted: {len(all_results)}")
    
    return all_results

# def extract_banking_entities(results, banking_terms):
#     """Extract banking entities using terms from CSV file"""
#     if not banking_terms:
#         print("No banking terms provided for entity extraction")
#         return []
    
#     entities = []
#     seen_entities = set()  # Track unique combinations
    
#     print(f"Searching for banking entities using {len(banking_terms)} terms...")
    
#     for i in range(len(results) - 1):
#         current_word = results[i]
#         next_word = results[i + 1]
        
#         # Check for banking term + noun
#         if current_word['word'] in banking_terms and next_word['pos'] == 'NOUN':
#             entity_text = f"{current_word['word']} {next_word['word']}"
#             if entity_text not in seen_entities:
#                 entity = {
#                     'entity': entity_text,
#                     'banking_term': current_word['word']
#                 }
#                 entities.append(entity)
#                 seen_entities.add(entity_text)
        
#         # Check for noun + banking term
#         elif current_word['pos'] == 'NOUN' and next_word['word'] in banking_terms:
#             entity_text = f"{current_word['word']} {next_word['word']}"
#             if entity_text not in seen_entities:
#                 entity = {
#                     'entity': entity_text,
#                     'banking_term': next_word['word']
#                 }
#                 entities.append(entity)
#                 seen_entities.add(entity_text)
    
#     print(f"Found {len(entities)} unique banking entities")
#     return entities

def save_results_csv(results, output_file):
    """Save POS tagging results to CSV"""
    try:
        with open(output_file, 'w', encoding='utf-8', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['کلمه', 'تگ', 'نقش'])
            
            for item in results:
                writer.writerow([item['word'], item['pos'], item['persian_pos']])
        
        print(f"POS results saved to {output_file}")
        return True
    except Exception as e:
        print(f"Error saving POS results: {e}")
        return False

# def save_banking_entities_csv(entities, output_file):
#     """Save banking entities to CSV"""
#     try:
#         with open(output_file, 'w', encoding='utf-8', newline='') as f:
#             writer = csv.writer(f)
#             writer.writerow(['واژه بانکی', 'ترکیب شناسایی شده'])
            
#             for entity in entities:
#                 writer.writerow([entity['banking_term'], entity['entity']])
        
#         print(f"Banking entities saved to {output_file}")
#         return True
#     except Exception as e:
#         print(f"Error saving banking entities CSV: {e}")
#         return False

# def save_banking_entities_excel(entities, output_file):
#     """Save banking entities to Excel"""
#     try:
#         data = {
#             'واژه بانکی': [entity['banking_term'] for entity in entities],
#             'ترکیب شناسایی شده': [entity['entity'] for entity in entities]
#         }
#         df = pd.DataFrame(data)
#         df.to_excel(output_file, index=False, engine='openpyxl')
#         print(f"Banking entities saved to {output_file}")
#         return True
#     except ImportError:
#         print("pandas or openpyxl not installed. Install with: pip install pandas openpyxl")
#         return False
#     except Exception as e:
#         print(f"Error saving banking entities Excel: {e}")
#         return False

def print_sample_results(results, sample_size=10):
    """Skip printing POS results - only save to files"""
    pass

def print_banking_entities(entities, max_display=20):
    """Skip printing banking entities - only save to files"""
    pass

def main():
    """Main execution function"""
    print("=== Persian Banking Entity Extractor ===\n")
    
    # File paths
    # banking_terms_file = "banking_terms.csv"
    input_file = "notices.txt"
    
    # Step 1: Load banking terms
    # print("Step 1: Loading banking terms...")
    # # banking_terms = read_banking_terms_from_csv(banking_terms_file)
    # if not banking_terms:
    #     print("❌ No banking terms loaded. Please create banking_terms.csv file.")
    #     return
    
    # Step 2: Read input text
    print("\nStep 2: Reading input text...")
    text = read_file(input_file)
    if not text:
        print("❌ Failed to read input text. Please check test.txt file.")
        return
    
    # Step 3: Process text for POS tagging
    print("\nStep 3: Processing text for POS tagging...")
    results = process_text_safely(text)
    if not results:
        print("❌ Text processing failed.")
        return
    
    # Step 4: Save POS results
    print("\nStep 4: Saving POS tagging results...")
    save_results_csv(results, "pos_output.csv")
    
    # Step 5: Extract banking entities
    # print("\nStep 5: Extracting banking entities...")
    # banking_entities = extract_banking_entities(results, banking_terms)
    
    # if not banking_entities:
    #     print("❌ No banking entities found in the text.")
    #     return
    
    # Step 6: Save banking entities (no printing)
    # print("\nStep 6: Saving banking entities...")
    
    # Save to CSV
    # save_banking_entities_csv(banking_entities, "banking_entities.csv")
    
    # # Save to Excel
    # save_banking_entities_excel(banking_entities, "banking_entities.xlsx")
    
    # Final summary
    print(f"\n=== Summary ===")
    print(f"✅ Text processed: {len(text)} characters")
    print(f"✅ Words analyzed: {len(results)}")
    # print(f"✅ Banking terms loaded: {len(banking_terms)}")
    # print(f"✅ Unique banking entities found: {len(banking_entities)}")
    print(f"✅ Output files created:")
    print(f"   - pos_output.csv (POS tagging results)")
    # print(f"   - banking_entities.csv (Banking entities)")
    # print(f"   - banking_entities.xlsx (Banking entities - Excel)")

# Execute main function
if __name__ == "__main__":
    main()
# Out:
# Initializing Persian NLP pipeline...
# === Persian Banking Entity Extractor ===
#
#
# Step 2: Reading input text...
# Successfully read 4512997 characters from notices.txt
#
# Step 3: Processing text for POS tagging...
# Starting text processing... (4512997 characters)
# Large text: split into 8380 word-based chunks
# Processing 8380 chunks...
# Processing chunk 1/8380 (557 characters)
# Chunk 1 processed: 100 words extracted
# Processing chunk 2/8380 (534 characters)
# Chunk 2 processed: 100 words extracted
# Processing chunk 3/8380 (521 characters)
# Chunk 3 processed: 101 words extracted
# Processing chunk 4/8380 (510 characters)
# Chunk 4 processed: 100 words extracted
# Processing chunk 5/8380 (488 characters)
# Chunk 5 processed: 100 words extracted
# Processing chunk 6/8380 (507 characters)
# Chunk 6 processed: 100 words extracted
# Processing chunk 7/8380 (504 characters)
# Chunk 7 processed: 100 words extracted
# Processing chunk 8/8380 (499 characters)
# Chunk 8 processed: 100 words extracted
# Processing chunk 9/8380 (544 characters)
# Chunk 9 processed: 100 words extracted
# Processing chunk 10/8380 (493 characters)
# Chunk 10 processed: 102 words extracted
# Processing chunk 11/8380 (496 characters)
# Chunk 11 processed: 100 words extracted
# Processing chunk 12/8380 (487 characters)
# Chunk 12 processed: 100 words extracted
# Processing chunk 13/8380 (518 characters)
# Chunk 13 processed: 100 words extracted
# Processing chunk 14/8380 (523 characters)
# Chunk 14 processed: 100 words extracted
# Processing chunk 15/8380 (523 characters)
# Chunk 15 processed: 100 words extracted
# Processing chunk 16/8380 (523 characters)
# Chunk 16 processed: 100 words extracted
# Processing chunk 17/8380 (527 characters)
# Chunk 17 processed: 100 words extracted
# Processing chunk 18/8380 (532 characters)
# Chunk 18 processed: 100 words extracted
# Processing chunk 19/8380 (494 characters)
# Chunk 19 processed: 100 words extracted
# Processing chunk 20/8380 (524 characters)
# Chunk 20 processed: 100 words extracted
# Processing chunk 21/8380 (508 characters)
# Chunk 21 processed: 100 words extracted
# Processing chunk 22/8380 (505 characters)
# Chunk 22 processed: 100 words extracted
# Processing chunk 23/8380 (507 characters)
# Chunk 23 processed: 100 words extracted
# Processing chunk 24/8380 (518 characters)
# Chunk 24 processed: 100 words extracted
# Processing chunk 25/8380 (509 characters)
# Chunk 25 processed: 100 words extracted
# Processing chunk 26/8380 (541 characters)
# Chunk 26 processed: 100 words extracted
# Processing chunk 27/8380 (493 characters)
# Chunk 27 processed: 100 words extracted
# Processing chunk 28/8380 (560 characters)
# Chunk 28 processed: 100 words extracted
# Processing chunk 29/8380 (538 characters)
# Chunk 29 processed: 100 words extracted
# Processing chunk 30/8380 (567 characters)
# Chunk 30 processed: 100 words extracted
# Processing chunk 31/8380 (591 characters)
# Chunk 31 processed: 100 words extracted
# Processing chunk 32/8380 (553 characters)
# Chunk 32 processed: 100 words extracted
# Processing chunk 33/8380 (521 characters)
# Chunk 33 processed: 100 words extracted
# Processing chunk 34/8380 (518 characters)
# Chunk 34 processed: 100 words extracted
# Processing chunk 35/8380 (530 characters)
# Chunk 35 processed: 100 words extracted
# Processing chunk 36/8380 (550 characters)
# Chunk 36 processed: 100 words extracted
# Processing chunk 37/8380 (519 characters)
# Chunk 37 processed: 100 words extracted
# Processing chunk 38/8380 (485 characters)
# Chunk 38 processed: 100 words extracted
# Processing chunk 39/8380 (478 characters)
# Chunk 39 processed: 100 words extracted
# Processing chunk 40/8380 (548 characters)
# Chunk 40 processed: 100 words extracted
# Processing chunk 41/8380 (530 characters)
# Chunk 41 processed: 100 words extracted
# Processing chunk 42/8380 (550 characters)
# Chunk 42 processed: 100 words extracted
# Processing chunk 43/8380 (514 characters)
# Chunk 43 processed: 100 words extracted
# Processing chunk 44/8380 (540 characters)
# Chunk 44 processed: 100 words extracted
# Processing chunk 45/8380 (507 characters)
# Chunk 45 processed: 100 words extracted
# Processing chunk 46/8380 (544 characters)
# Chunk 46 processed: 100 words extracted
# Processing chunk 47/8380 (550 characters)
# Chunk 47 processed: 100 words extracted
# Processing chunk 48/8380 (488 characters)
# Chunk 48 processed: 100 words extracted
# Processing chunk 49/8380 (513 characters)
# Chunk 49 processed: 100 words extracted
# Processing chunk 50/8380 (478 characters)
# Chunk 50 processed: 100 words extracted
# Processing chunk 51/8380 (537 characters)
# Chunk 51 processed: 100 words extracted
# Processing chunk 52/8380 (517 characters)
# Chunk 52 processed: 100 words extracted
# Processing chunk 53/8380 (505 characters)
# Chunk 53 processed: 100 words extracted
# Processing chunk 54/8380 (515 characters)
# Chunk 54 processed: 100 words extracted
# Processing chunk 55/8380 (526 characters)
# Chunk 55 processed: 100 words extracted
# Processing chunk 56/8380 (480 characters)
# Chunk 56 processed: 100 words extracted
# Processing chunk 57/8380 (475 characters)
# Chunk 57 processed: 100 words extracted
# Processing chunk 58/8380 (501 characters)
# Chunk 58 processed: 100 words extracted
# Processing chunk 59/8380 (517 characters)
# Chunk 59 processed: 100 words extracted
# Processing chunk 60/8380 (532 characters)
# Chunk 60 processed: 100 words extracted
# Processing chunk 61/8380 (559 characters)
# Chunk 61 processed: 100 words extracted
# Processing chunk 62/8380 (570 characters)
# Chunk 62 processed: 100 words extracted
# Processing chunk 63/8380 (507 characters)
# Chunk 63 processed: 100 words extracted
# Processing chunk 64/8380 (568 characters)
# Chunk 64 processed: 100 words extracted
# Processing chunk 65/8380 (537 characters)
# Chunk 65 processed: 100 words extracted
# Processing chunk 66/8380 (539 characters)
# Chunk 66 processed: 100 words extracted
# Processing chunk 67/8380 (569 characters)
# Chunk 67 processed: 100 words extracted
# Processing chunk 68/8380 (535 characters)
# Chunk 68 processed: 100 words extracted
# Processing chunk 69/8380 (511 characters)
# Chunk 69 processed: 100 words extracted
# Processing chunk 70/8380 (483 characters)
# Chunk 70 processed: 100 words extracted
# Processing chunk 71/8380 (522 characters)
# Chunk 71 processed: 100 words extracted
# Processing chunk 72/8380 (519 characters)
# Chunk 72 processed: 100 words extracted
# Processing chunk 73/8380 (493 characters)
# Chunk 73 processed: 101 words extracted
# Processing chunk 74/8380 (510 characters)
# Chunk 74 processed: 100 words extracted
# Processing chunk 75/8380 (517 characters)
# Chunk 75 processed: 100 words extracted
# Processing chunk 76/8380 (518 characters)
# Chunk 76 processed: 100 words extracted
# Processing chunk 77/8380 (514 characters)
# Chunk 77 processed: 100 words extracted
# Processing chunk 78/8380 (500 characters)
# Chunk 78 processed: 100 words extracted
# Processing chunk 79/8380 (511 characters)
# Chunk 79 processed: 100 words extracted
# Processing chunk 80/8380 (505 characters)
# Chunk 80 processed: 100 words extracted
# Processing chunk 81/8380 (513 characters)
# Chunk 81 processed: 100 words extracted
# Processing chunk 82/8380 (519 characters)
# Chunk 82 processed: 100 words extracted
# Processing chunk 83/8380 (514 characters)
# Chunk 83 processed: 100 words extracted
# Processing chunk 84/8380 (531 characters)
# Chunk 84 processed: 100 words extracted
# Processing chunk 85/8380 (497 characters)
# Chunk 85 processed: 100 words extracted
# Processing chunk 86/8380 (546 characters)
# Chunk 86 processed: 100 words extracted
# Processing chunk 87/8380 (485 characters)
# Chunk 87 processed: 100 words extracted
# Processing chunk 88/8380 (560 characters)
# Chunk 88 processed: 100 words extracted
# Processing chunk 89/8380 (526 characters)
# Chunk 89 processed: 100 words extracted
# Processing chunk 90/8380 (542 characters)
# Chunk 90 processed: 102 words extracted
# Processing chunk 91/8380 (544 characters)
# Chunk 91 processed: 100 words extracted
# Processing chunk 92/8380 (525 characters)
# Chunk 92 processed: 100 words extracted
# Processing chunk 93/8380 (498 characters)
# Chunk 93 processed: 100 words extracted
# Processing chunk 94/8380 (512 characters)
# Chunk 94 processed: 100 words extracted
# Processing chunk 95/8380 (529 characters)
# Chunk 95 processed: 100 words extracted
# Processing chunk 96/8380 (519 characters)
# Chunk 96 processed: 100 words extracted
# Processing chunk 97/8380 (502 characters)
# Chunk 97 processed: 100 words extracted
# Processing chunk 98/8380 (506 characters)
# Chunk 98 processed: 100 words extracted
# Processing chunk 99/8380 (577 characters)
# Chunk 99 processed: 100 words extracted
# Processing chunk 100/8380 (557 characters)
# Chunk 100 processed: 100 words extracted
# Processing chunk 101/8380 (488 characters)
# Chunk 101 processed: 100 words extracted
# Processing chunk 102/8380 (548 characters)
# Chunk 102 processed: 100 words extracted
# Processing chunk 103/8380 (550 characters)
# Chunk 103 processed: 100 words extracted
# Processing chunk 104/8380 (506 characters)
# Chunk 104 processed: 100 words extracted
# Processing chunk 105/8380 (513 characters)
# Chunk 105 processed: 100 words extracted
# Processing chunk 106/8380 (508 characters)
# Chunk 106 processed: 100 words extracted
# Processing chunk 107/8380 (542 characters)
# Chunk 107 processed: 100 words extracted
# Processing chunk 108/8380 (549 characters)
# Chunk 108 processed: 100 words extracted
# Processing chunk 109/8380 (505 characters)
# Chunk 109 processed: 100 words extracted
# Processing chunk 110/8380 (552 characters)
# Chunk 110 processed: 100 words extracted
# Processing chunk 111/8380 (513 characters)
# Chunk 111 processed: 100 words extracted
# Processing chunk 112/8380 (514 characters)
# Chunk 112 processed: 100 words extracted
# Processing chunk 113/8380 (529 characters)
# Chunk 113 processed: 100 words extracted
# Processing chunk 114/8380 (517 characters)
# Chunk 114 processed: 100 words extracted
# Processing chunk 115/8380 (512 characters)
# Chunk 115 processed: 100 words extracted
# Processing chunk 116/8380 (562 characters)
# Chunk 116 processed: 100 words extracted
# Processing chunk 117/8380 (551 characters)
# Chunk 117 processed: 100 words extracted
# Processing chunk 118/8380 (532 characters)
# Chunk 118 processed: 100 words extracted
# Processing chunk 119/8380 (515 characters)
# Chunk 119 processed: 100 words extracted
# Processing chunk 120/8380 (509 characters)
# Chunk 120 processed: 100 words extracted
# Processing chunk 121/8380 (543 characters)
# Chunk 121 processed: 100 words extracted
# Processing chunk 122/8380 (531 characters)
# Chunk 122 processed: 100 words extracted
# Processing chunk 123/8380 (520 characters)
# Chunk 123 processed: 100 words extracted
# Processing chunk 124/8380 (536 characters)
# Chunk 124 processed: 100 words extracted
# Processing chunk 125/8380 (542 characters)
# Chunk 125 processed: 100 words extracted
# Processing chunk 126/8380 (516 characters)
# Chunk 126 processed: 100 words extracted
# Processing chunk 127/8380 (502 characters)
# Chunk 127 processed: 100 words extracted
# Processing chunk 128/8380 (520 characters)
# Chunk 128 processed: 100 words extracted
# Processing chunk 129/8380 (538 characters)
# Chunk 129 processed: 100 words extracted
# Processing chunk 130/8380 (509 characters)
# Chunk 130 processed: 100 words extracted
# Processing chunk 131/8380 (536 characters)
# Chunk 131 processed: 100 words extracted
# Processing chunk 132/8380 (546 characters)
# Chunk 132 processed: 100 words extracted
# Processing chunk 133/8380 (549 characters)
# Chunk 133 processed: 100 words extracted
# Processing chunk 134/8380 (538 characters)
# Chunk 134 processed: 100 words extracted
# Processing chunk 135/8380 (515 characters)
# Chunk 135 processed: 100 words extracted
# Processing chunk 136/8380 (527 characters)
# Chunk 136 processed: 100 words extracted
# Processing chunk 137/8380 (519 characters)
# Chunk 137 processed: 100 words extracted
# Processing chunk 138/8380 (521 characters)
# Chunk 138 processed: 100 words extracted
# Processing chunk 139/8380 (503 characters)
# Chunk 139 processed: 100 words extracted
# Processing chunk 140/8380 (528 characters)
# Chunk 140 processed: 100 words extracted
# Processing chunk 141/8380 (488 characters)
# Chunk 141 processed: 100 words extracted
# Processing chunk 142/8380 (557 characters)
# Chunk 142 processed: 100 words extracted
# Processing chunk 143/8380 (519 characters)
# Chunk 143 processed: 100 words extracted
# Processing chunk 144/8380 (535 characters)
# Chunk 144 processed: 100 words extracted
# Processing chunk 145/8380 (534 characters)
# Chunk 145 processed: 101 words extracted
# Processing chunk 146/8380 (502 characters)
# Chunk 146 processed: 100 words extracted
# Processing chunk 147/8380 (482 characters)
# Chunk 147 processed: 100 words extracted
# Processing chunk 148/8380 (555 characters)
# Chunk 148 processed: 100 words extracted
# Processing chunk 149/8380 (576 characters)
# Chunk 149 processed: 100 words extracted
# Processing chunk 150/8380 (503 characters)
# Chunk 150 processed: 100 words extracted
# Processing chunk 151/8380 (495 characters)
# Chunk 151 processed: 100 words extracted
# Processing chunk 152/8380 (542 characters)
# Chunk 152 processed: 100 words extracted
# Processing chunk 153/8380 (543 characters)
# Chunk 153 processed: 100 words extracted
# Processing chunk 154/8380 (540 characters)
# Chunk 154 processed: 100 words extracted
# Processing chunk 155/8380 (533 characters)
# Chunk 155 processed: 100 words extracted
# Processing chunk 156/8380 (574 characters)
# Chunk 156 processed: 100 words extracted
# Processing chunk 157/8380 (544 characters)
# Chunk 157 processed: 100 words extracted
# Processing chunk 158/8380 (527 characters)
# Chunk 158 processed: 102 words extracted
# Processing chunk 159/8380 (527 characters)
# Chunk 159 processed: 101 words extracted
# Processing chunk 160/8380 (520 characters)
# Chunk 160 processed: 100 words extracted
# Processing chunk 161/8380 (557 characters)
# Chunk 161 processed: 100 words extracted
# Processing chunk 162/8380 (534 characters)
# Chunk 162 processed: 100 words extracted
# Processing chunk 163/8380 (525 characters)
# Chunk 163 processed: 100 words extracted
# Processing chunk 164/8380 (560 characters)
# Chunk 164 processed: 100 words extracted
# Processing chunk 165/8380 (548 characters)
# Chunk 165 processed: 100 words extracted
# Processing chunk 166/8380 (522 characters)
# Chunk 166 processed: 101 words extracted
# Processing chunk 167/8380 (551 characters)
# Chunk 167 processed: 100 words extracted
# Processing chunk 168/8380 (532 characters)
# Chunk 168 processed: 100 words extracted
# Processing chunk 169/8380 (538 characters)
# Chunk 169 processed: 100 words extracted
# Processing chunk 170/8380 (496 characters)
# Chunk 170 processed: 100 words extracted
# Processing chunk 171/8380 (480 characters)
# Chunk 171 processed: 101 words extracted
# Processing chunk 172/8380 (504 characters)
# Chunk 172 processed: 100 words extracted
# Processing chunk 173/8380 (520 characters)
# Chunk 173 processed: 100 words extracted
# Processing chunk 174/8380 (526 characters)
# Chunk 174 processed: 100 words extracted
# Processing chunk 175/8380 (556 characters)
# Chunk 175 processed: 100 words extracted
# Processing chunk 176/8380 (564 characters)
# Chunk 176 processed: 100 words extracted
# Processing chunk 177/8380 (522 characters)
# Chunk 177 processed: 100 words extracted
# Processing chunk 178/8380 (506 characters)
# Chunk 178 processed: 101 words extracted
# Processing chunk 179/8380 (488 characters)
# Chunk 179 processed: 100 words extracted
# Processing chunk 180/8380 (536 characters)
# Chunk 180 processed: 100 words extracted
# Processing chunk 181/8380 (544 characters)
# Chunk 181 processed: 100 words extracted
# Processing chunk 182/8380 (542 characters)
# Chunk 182 processed: 100 words extracted
# Processing chunk 183/8380 (544 characters)
# Chunk 183 processed: 100 words extracted
# Processing chunk 184/8380 (514 characters)
# Chunk 184 processed: 100 words extracted
# Processing chunk 185/8380 (522 characters)
# Chunk 185 processed: 100 words extracted
# Processing chunk 186/8380 (543 characters)
# Chunk 186 processed: 100 words extracted
# Processing chunk 187/8380 (529 characters)
# Chunk 187 processed: 100 words extracted
# Processing chunk 188/8380 (562 characters)
# Chunk 188 processed: 100 words extracted
# Processing chunk 189/8380 (540 characters)
# Chunk 189 processed: 100 words extracted
# Processing chunk 190/8380 (491 characters)
# Chunk 190 processed: 100 words extracted
# Processing chunk 191/8380 (531 characters)
# Chunk 191 processed: 100 words extracted
# Processing chunk 192/8380 (528 characters)
# Chunk 192 processed: 101 words extracted
# Processing chunk 193/8380 (538 characters)
# Chunk 193 processed: 100 words extracted
# Processing chunk 194/8380 (510 characters)
# Chunk 194 processed: 100 words extracted
# Processing chunk 195/8380 (511 characters)
# Chunk 195 processed: 100 words extracted
# Processing chunk 196/8380 (545 characters)
# Chunk 196 processed: 100 words extracted
# Processing chunk 197/8380 (574 characters)
# Chunk 197 processed: 100 words extracted
# Processing chunk 198/8380 (529 characters)
# Chunk 198 processed: 100 words extracted
# Processing chunk 199/8380 (548 characters)
# Chunk 199 processed: 100 words extracted
# Processing chunk 200/8380 (547 characters)
# Chunk 200 processed: 100 words extracted
# Processing chunk 201/8380 (516 characters)
# Chunk 201 processed: 100 words extracted
# Processing chunk 202/8380 (541 characters)
# Chunk 202 processed: 100 words extracted
# Processing chunk 203/8380 (536 characters)
# Chunk 203 processed: 100 words extracted
# Processing chunk 204/8380 (525 characters)
# Chunk 204 processed: 100 words extracted
# Processing chunk 205/8380 (523 characters)
# Chunk 205 processed: 100 words extracted
# Processing chunk 206/8380 (494 characters)
# Chunk 206 processed: 100 words extracted
# Processing chunk 207/8380 (563 characters)
# Chunk 207 processed: 100 words extracted
# Processing chunk 208/8380 (535 characters)
# Chunk 208 processed: 100 words extracted
# Processing chunk 209/8380 (521 characters)
# Chunk 209 processed: 100 words extracted
# Processing chunk 210/8380 (504 characters)
# Chunk 210 processed: 100 words extracted
# Processing chunk 211/8380 (528 characters)
# Chunk 211 processed: 100 words extracted
# Processing chunk 212/8380 (532 characters)
# Chunk 212 processed: 100 words extracted
# Processing chunk 213/8380 (516 characters)
# Chunk 213 processed: 100 words extracted
# Processing chunk 214/8380 (512 characters)
# Chunk 214 processed: 100 words extracted
# Processing chunk 215/8380 (513 characters)
# Chunk 215 processed: 100 words extracted
# Processing chunk 216/8380 (517 characters)
# Chunk 216 processed: 100 words extracted
# Processing chunk 217/8380 (532 characters)
# Chunk 217 processed: 100 words extracted
# Processing chunk 218/8380 (582 characters)
# Chunk 218 processed: 101 words extracted
# Processing chunk 219/8380 (560 characters)
# Chunk 219 processed: 100 words extracted
# Processing chunk 220/8380 (560 characters)
# Chunk 220 processed: 100 words extracted
# Processing chunk 221/8380 (512 characters)
# Chunk 221 processed: 100 words extracted
# Processing chunk 222/8380 (519 characters)
# Chunk 222 processed: 100 words extracted
# Processing chunk 223/8380 (523 characters)
# Chunk 223 processed: 100 words extracted
# Processing chunk 224/8380 (518 characters)
# Chunk 224 processed: 100 words extracted
# Processing chunk 225/8380 (450 characters)
# Chunk 225 processed: 100 words extracted
# Processing chunk 226/8380 (465 characters)
# Chunk 226 processed: 100 words extracted
# Processing chunk 227/8380 (496 characters)
# Chunk 227 processed: 100 words extracted
# Processing chunk 228/8380 (529 characters)
# Chunk 228 processed: 100 words extracted
# Processing chunk 229/8380 (540 characters)
# Chunk 229 processed: 100 words extracted
# Processing chunk 230/8380 (548 characters)
# Chunk 230 processed: 100 words extracted
# Processing chunk 231/8380 (534 characters)
# Chunk 231 processed: 100 words extracted
# Processing chunk 232/8380 (543 characters)
# Chunk 232 processed: 100 words extracted
# Processing chunk 233/8380 (539 characters)
# Chunk 233 processed: 100 words extracted
# Processing chunk 234/8380 (522 characters)
# Chunk 234 processed: 100 words extracted
# Processing chunk 235/8380 (558 characters)
# Chunk 235 processed: 100 words extracted
# Processing chunk 236/8380 (499 characters)
# Chunk 236 processed: 100 words extracted
# Processing chunk 237/8380 (539 characters)
# Chunk 237 processed: 100 words extracted
# Processing chunk 238/8380 (563 characters)
# Chunk 238 processed: 100 words extracted
# Processing chunk 239/8380 (527 characters)
# Chunk 239 processed: 100 words extracted
# Processing chunk 240/8380 (493 characters)
# Chunk 240 processed: 100 words extracted
# Processing chunk 241/8380 (515 characters)
# Chunk 241 processed: 100 words extracted
# Processing chunk 242/8380 (461 characters)
# Chunk 242 processed: 100 words extracted
# Processing chunk 243/8380 (538 characters)
# Chunk 243 processed: 100 words extracted
# Processing chunk 244/8380 (535 characters)
# Chunk 244 processed: 100 words extracted
# Processing chunk 245/8380 (522 characters)
# Chunk 245 processed: 101 words extracted
# Processing chunk 246/8380 (528 characters)
# Chunk 246 processed: 100 words extracted
# Processing chunk 247/8380 (523 characters)
# Chunk 247 processed: 100 words extracted
# Processing chunk 248/8380 (497 characters)
# Chunk 248 processed: 100 words extracted
# Processing chunk 249/8380 (559 characters)
# Chunk 249 processed: 100 words extracted
# Processing chunk 250/8380 (549 characters)
# Chunk 250 processed: 100 words extracted
# Processing chunk 251/8380 (518 characters)
# Chunk 251 processed: 100 words extracted
# Processing chunk 252/8380 (533 characters)
# Chunk 252 processed: 100 words extracted
# Processing chunk 253/8380 (499 characters)
# Chunk 253 processed: 100 words extracted
# Processing chunk 254/8380 (534 characters)
# Chunk 254 processed: 100 words extracted
# Processing chunk 255/8380 (528 characters)
# Chunk 255 processed: 100 words extracted
# Processing chunk 256/8380 (533 characters)
# Chunk 256 processed: 100 words extracted
# Processing chunk 257/8380 (550 characters)
# Chunk 257 processed: 100 words extracted
# Processing chunk 258/8380 (554 characters)
# Chunk 258 processed: 100 words extracted
# Processing chunk 259/8380 (503 characters)
# Chunk 259 processed: 100 words extracted
# Processing chunk 260/8380 (490 characters)
# Chunk 260 processed: 100 words extracted
# Processing chunk 261/8380 (471 characters)
# Chunk 261 processed: 100 words extracted
# Processing chunk 262/8380 (522 characters)
# Chunk 262 processed: 100 words extracted
# Processing chunk 263/8380 (468 characters)
# Chunk 263 processed: 100 words extracted
# Processing chunk 264/8380 (500 characters)
# Chunk 264 processed: 100 words extracted
# Processing chunk 265/8380 (547 characters)
# Chunk 265 processed: 100 words extracted
# Processing chunk 266/8380 (515 characters)
# Chunk 266 processed: 100 words extracted
# Processing chunk 267/8380 (518 characters)
# Chunk 267 processed: 100 words extracted
# Processing chunk 268/8380 (546 characters)
# Chunk 268 processed: 100 words extracted
# Processing chunk 269/8380 (584 characters)
# Chunk 269 processed: 100 words extracted
# Processing chunk 270/8380 (534 characters)
# Chunk 270 processed: 100 words extracted
# Processing chunk 271/8380 (511 characters)
# Chunk 271 processed: 101 words extracted
# Processing chunk 272/8380 (527 characters)
# Chunk 272 processed: 101 words extracted
# Processing chunk 273/8380 (468 characters)
# Chunk 273 processed: 100 words extracted
# Processing chunk 274/8380 (474 characters)
# Chunk 274 processed: 100 words extracted
# Processing chunk 275/8380 (568 characters)
# Chunk 275 processed: 100 words extracted
# Processing chunk 276/8380 (531 characters)
# Chunk 276 processed: 100 words extracted
# Processing chunk 277/8380 (532 characters)
# Chunk 277 processed: 100 words extracted
# Processing chunk 278/8380 (490 characters)
# Chunk 278 processed: 100 words extracted
# Processing chunk 279/8380 (577 characters)
# Chunk 279 processed: 100 words extracted
# Processing chunk 280/8380 (539 characters)
# Chunk 280 processed: 100 words extracted
# Processing chunk 281/8380 (536 characters)
# Chunk 281 processed: 100 words extracted
# Processing chunk 282/8380 (512 characters)
# Chunk 282 processed: 100 words extracted
# Processing chunk 283/8380 (515 characters)
# Chunk 283 processed: 100 words extracted
# Processing chunk 284/8380 (588 characters)
# Chunk 284 processed: 100 words extracted
# Processing chunk 285/8380 (550 characters)
# Chunk 285 processed: 102 words extracted
# Processing chunk 286/8380 (521 characters)
# Chunk 286 processed: 101 words extracted
# Processing chunk 287/8380 (555 characters)
# Chunk 287 processed: 100 words extracted
# Processing chunk 288/8380 (529 characters)
# Chunk 288 processed: 100 words extracted
# Processing chunk 289/8380 (545 characters)
# Chunk 289 processed: 100 words extracted
# Processing chunk 290/8380 (568 characters)
# Chunk 290 processed: 100 words extracted
# Processing chunk 291/8380 (550 characters)
# Chunk 291 processed: 100 words extracted
# Processing chunk 292/8380 (538 characters)
# Chunk 292 processed: 100 words extracted
# Processing chunk 293/8380 (462 characters)
# Chunk 293 processed: 100 words extracted
# Processing chunk 294/8380 (564 characters)
# Chunk 294 processed: 102 words extracted
# Processing chunk 295/8380 (512 characters)
# Chunk 295 processed: 100 words extracted
# Processing chunk 296/8380 (535 characters)
# Chunk 296 processed: 100 words extracted
# Processing chunk 297/8380 (546 characters)
# Chunk 297 processed: 100 words extracted
# Processing chunk 298/8380 (561 characters)
# Chunk 298 processed: 100 words extracted
# Processing chunk 299/8380 (497 characters)
# Chunk 299 processed: 100 words extracted
# Processing chunk 300/8380 (554 characters)
# Chunk 300 processed: 100 words extracted
# Processing chunk 301/8380 (530 characters)
# Chunk 301 processed: 100 words extracted
# Processing chunk 302/8380 (504 characters)
# Chunk 302 processed: 103 words extracted
# Processing chunk 303/8380 (513 characters)
# Chunk 303 processed: 100 words extracted
# Processing chunk 304/8380 (535 characters)
# Chunk 304 processed: 100 words extracted
# Processing chunk 305/8380 (551 characters)
# Chunk 305 processed: 100 words extracted
# Processing chunk 306/8380 (462 characters)
# Chunk 306 processed: 100 words extracted
# Processing chunk 307/8380 (498 characters)
# Chunk 307 processed: 100 words extracted
# Processing chunk 308/8380 (537 characters)
# Chunk 308 processed: 100 words extracted
# Processing chunk 309/8380 (560 characters)
# Chunk 309 processed: 100 words extracted
# Processing chunk 310/8380 (504 characters)
# Chunk 310 processed: 100 words extracted
# Processing chunk 311/8380 (514 characters)
# Chunk 311 processed: 100 words extracted
# Processing chunk 312/8380 (528 characters)
# Chunk 312 processed: 100 words extracted
# Processing chunk 313/8380 (542 characters)
# Chunk 313 processed: 100 words extracted
# Processing chunk 314/8380 (517 characters)
# Chunk 314 processed: 100 words extracted
# Processing chunk 315/8380 (549 characters)
# Chunk 315 processed: 100 words extracted
# Processing chunk 316/8380 (530 characters)
# Chunk 316 processed: 100 words extracted
# Processing chunk 317/8380 (527 characters)
# Chunk 317 processed: 100 words extracted
# Processing chunk 318/8380 (526 characters)
# Chunk 318 processed: 100 words extracted
# Processing chunk 319/8380 (512 characters)
# Chunk 319 processed: 100 words extracted
# Processing chunk 320/8380 (544 characters)
# Chunk 320 processed: 100 words extracted
# Processing chunk 321/8380 (502 characters)
# Chunk 321 processed: 100 words extracted
# Processing chunk 322/8380 (568 characters)
# Chunk 322 processed: 100 words extracted
# Processing chunk 323/8380 (516 characters)
# Chunk 323 processed: 100 words extracted
# Processing chunk 324/8380 (548 characters)
# Chunk 324 processed: 100 words extracted
# Processing chunk 325/8380 (543 characters)
# Chunk 325 processed: 100 words extracted
# Processing chunk 326/8380 (537 characters)
# Chunk 326 processed: 100 words extracted
# Processing chunk 327/8380 (483 characters)
# Chunk 327 processed: 100 words extracted
# Processing chunk 328/8380 (523 characters)
# Chunk 328 processed: 100 words extracted
# Processing chunk 329/8380 (525 characters)
# Chunk 329 processed: 99 words extracted
# Processing chunk 330/8380 (571 characters)
# Chunk 330 processed: 100 words extracted
# Processing chunk 331/8380 (520 characters)
# Chunk 331 processed: 100 words extracted
# Processing chunk 332/8380 (549 characters)
# Chunk 332 processed: 100 words extracted
# Processing chunk 333/8380 (537 characters)
# Chunk 333 processed: 100 words extracted
# Processing chunk 334/8380 (526 characters)
# Chunk 334 processed: 100 words extracted
# Processing chunk 335/8380 (505 characters)
# Chunk 335 processed: 100 words extracted
# Processing chunk 336/8380 (506 characters)
# Chunk 336 processed: 100 words extracted
# Processing chunk 337/8380 (576 characters)
# Chunk 337 processed: 100 words extracted
# Processing chunk 338/8380 (557 characters)
# Chunk 338 processed: 100 words extracted
# Processing chunk 339/8380 (529 characters)
# Chunk 339 processed: 100 words extracted
# Processing chunk 340/8380 (544 characters)
# Chunk 340 processed: 100 words extracted
# Processing chunk 341/8380 (487 characters)
# Chunk 341 processed: 100 words extracted
# Processing chunk 342/8380 (510 characters)
# Chunk 342 processed: 100 words extracted
# Processing chunk 343/8380 (570 characters)
# Chunk 343 processed: 100 words extracted
# Processing chunk 344/8380 (552 characters)
# Chunk 344 processed: 100 words extracted
# Processing chunk 345/8380 (554 characters)
# Chunk 345 processed: 100 words extracted
# Processing chunk 346/8380 (547 characters)
# Chunk 346 processed: 100 words extracted
# Processing chunk 347/8380 (525 characters)
# Chunk 347 processed: 100 words extracted
# Processing chunk 348/8380 (536 characters)
# Chunk 348 processed: 100 words extracted
# Processing chunk 349/8380 (499 characters)
# Chunk 349 processed: 100 words extracted
# Processing chunk 350/8380 (508 characters)
# Chunk 350 processed: 100 words extracted
# Processing chunk 351/8380 (514 characters)
# Chunk 351 processed: 100 words extracted
# Processing chunk 352/8380 (503 characters)
# Chunk 352 processed: 100 words extracted
# Processing chunk 353/8380 (520 characters)
# Chunk 353 processed: 100 words extracted
# Processing chunk 354/8380 (533 characters)
# Chunk 354 processed: 100 words extracted
# Processing chunk 355/8380 (557 characters)
# Chunk 355 processed: 100 words extracted
# Processing chunk 356/8380 (520 characters)
# Chunk 356 processed: 100 words extracted
# Processing chunk 357/8380 (554 characters)
# Chunk 357 processed: 100 words extracted
# Processing chunk 358/8380 (534 characters)
# Chunk 358 processed: 100 words extracted
# Processing chunk 359/8380 (537 characters)
# Chunk 359 processed: 101 words extracted
# Processing chunk 360/8380 (500 characters)
# Chunk 360 processed: 101 words extracted
# Processing chunk 361/8380 (493 characters)
# Chunk 361 processed: 100 words extracted
# Processing chunk 362/8380 (549 characters)
# Chunk 362 processed: 100 words extracted
# Processing chunk 363/8380 (529 characters)
# Chunk 363 processed: 100 words extracted
# Processing chunk 364/8380 (524 characters)
# Chunk 364 processed: 100 words extracted
# Processing chunk 365/8380 (487 characters)
# Chunk 365 processed: 100 words extracted
# Processing chunk 366/8380 (508 characters)
# Chunk 366 processed: 100 words extracted
# Processing chunk 367/8380 (489 characters)
# Chunk 367 processed: 100 words extracted
# Processing chunk 368/8380 (477 characters)
# Chunk 368 processed: 100 words extracted
# Processing chunk 369/8380 (490 characters)
# Chunk 369 processed: 100 words extracted
# Processing chunk 370/8380 (528 characters)
# Chunk 370 processed: 100 words extracted
# Processing chunk 371/8380 (541 characters)
# Chunk 371 processed: 100 words extracted
# Processing chunk 372/8380 (540 characters)
# Chunk 372 processed: 100 words extracted
# Processing chunk 373/8380 (575 characters)
# Chunk 373 processed: 100 words extracted
# Processing chunk 374/8380 (498 characters)
# Chunk 374 processed: 100 words extracted
# Processing chunk 375/8380 (490 characters)
# Chunk 375 processed: 100 words extracted
# Processing chunk 376/8380 (528 characters)
# Chunk 376 processed: 100 words extracted
# Processing chunk 377/8380 (518 characters)
# Chunk 377 processed: 100 words extracted
# Processing chunk 378/8380 (521 characters)
# Chunk 378 processed: 100 words extracted
# Processing chunk 379/8380 (514 characters)
# Chunk 379 processed: 101 words extracted
# Processing chunk 380/8380 (579 characters)
# Chunk 380 processed: 100 words extracted
# Processing chunk 381/8380 (560 characters)
# Chunk 381 processed: 100 words extracted
# Processing chunk 382/8380 (546 characters)
# Chunk 382 processed: 100 words extracted
# Processing chunk 383/8380 (526 characters)
# Chunk 383 processed: 100 words extracted
# Processing chunk 384/8380 (523 characters)
# Chunk 384 processed: 100 words extracted
# Processing chunk 385/8380 (536 characters)
# Chunk 385 processed: 100 words extracted
# Processing chunk 386/8380 (558 characters)
# Chunk 386 processed: 100 words extracted
# Processing chunk 387/8380 (528 characters)
# Chunk 387 processed: 100 words extracted
# Processing chunk 388/8380 (532 characters)
# Chunk 388 processed: 100 words extracted
# Processing chunk 389/8380 (530 characters)
# Chunk 389 processed: 100 words extracted
# Processing chunk 390/8380 (535 characters)
# Chunk 390 processed: 100 words extracted
# Processing chunk 391/8380 (498 characters)
# Chunk 391 processed: 100 words extracted
# Processing chunk 392/8380 (474 characters)
# Chunk 392 processed: 100 words extracted
# Processing chunk 393/8380 (501 characters)
# Chunk 393 processed: 100 words extracted
# Processing chunk 394/8380 (466 characters)
# Chunk 394 processed: 100 words extracted
# Processing chunk 395/8380 (532 characters)
# Chunk 395 processed: 100 words extracted
# Processing chunk 396/8380 (521 characters)
# Chunk 396 processed: 100 words extracted
# Processing chunk 397/8380 (529 characters)
# Chunk 397 processed: 100 words extracted
# Processing chunk 398/8380 (545 characters)
# Chunk 398 processed: 100 words extracted
# Processing chunk 399/8380 (549 characters)
# Chunk 399 processed: 100 words extracted
# Processing chunk 400/8380 (560 characters)
# Chunk 400 processed: 100 words extracted
# Processing chunk 401/8380 (474 characters)
# Chunk 401 processed: 100 words extracted
# Processing chunk 402/8380 (562 characters)
# Chunk 402 processed: 100 words extracted
# Processing chunk 403/8380 (525 characters)
# Chunk 403 processed: 100 words extracted
# Processing chunk 404/8380 (489 characters)
# Chunk 404 processed: 100 words extracted
# Processing chunk 405/8380 (513 characters)
# Chunk 405 processed: 100 words extracted
# Processing chunk 406/8380 (567 characters)
# Chunk 406 processed: 100 words extracted
# Processing chunk 407/8380 (535 characters)
# Chunk 407 processed: 100 words extracted
# Processing chunk 408/8380 (501 characters)
# Chunk 408 processed: 100 words extracted
# Processing chunk 409/8380 (507 characters)
# Chunk 409 processed: 100 words extracted
# Processing chunk 410/8380 (563 characters)
# Chunk 410 processed: 100 words extracted
# Processing chunk 411/8380 (557 characters)
# Chunk 411 processed: 100 words extracted
# Processing chunk 412/8380 (521 characters)
# Chunk 412 processed: 100 words extracted
# Processing chunk 413/8380 (548 characters)
# Chunk 413 processed: 100 words extracted
# Processing chunk 414/8380 (581 characters)
# Chunk 414 processed: 100 words extracted
# Processing chunk 415/8380 (524 characters)
# Chunk 415 processed: 100 words extracted
# Processing chunk 416/8380 (508 characters)
# Chunk 416 processed: 100 words extracted
# Processing chunk 417/8380 (511 characters)
# Chunk 417 processed: 100 words extracted
# Processing chunk 418/8380 (550 characters)
# Chunk 418 processed: 100 words extracted
# Processing chunk 419/8380 (517 characters)
# Chunk 419 processed: 100 words extracted
# Processing chunk 420/8380 (506 characters)
# Chunk 420 processed: 100 words extracted
# Processing chunk 421/8380 (510 characters)
# Chunk 421 processed: 100 words extracted
# Processing chunk 422/8380 (536 characters)
# Chunk 422 processed: 100 words extracted
# Processing chunk 423/8380 (510 characters)
# Chunk 423 processed: 100 words extracted
# Processing chunk 424/8380 (519 characters)
# Chunk 424 processed: 100 words extracted
# Processing chunk 425/8380 (484 characters)
# Chunk 425 processed: 100 words extracted
# Processing chunk 426/8380 (469 characters)
# Chunk 426 processed: 100 words extracted
# Processing chunk 427/8380 (538 characters)
# Chunk 427 processed: 100 words extracted
# Processing chunk 428/8380 (526 characters)
# Chunk 428 processed: 100 words extracted
# Processing chunk 429/8380 (532 characters)
# Chunk 429 processed: 100 words extracted
# Processing chunk 430/8380 (496 characters)
# Chunk 430 processed: 100 words extracted
# Processing chunk 431/8380 (537 characters)
# Chunk 431 processed: 100 words extracted
# Processing chunk 432/8380 (521 characters)
# Chunk 432 processed: 100 words extracted
# Processing chunk 433/8380 (563 characters)
# Chunk 433 processed: 100 words extracted
# Processing chunk 434/8380 (568 characters)
# Chunk 434 processed: 100 words extracted
# Processing chunk 435/8380 (529 characters)
# Chunk 435 processed: 100 words extracted
# Processing chunk 436/8380 (525 characters)
# Chunk 436 processed: 100 words extracted
# Processing chunk 437/8380 (534 characters)
# Chunk 437 processed: 100 words extracted
# Processing chunk 438/8380 (523 characters)
# Chunk 438 processed: 100 words extracted
# Processing chunk 439/8380 (559 characters)
# Chunk 439 processed: 100 words extracted
# Processing chunk 440/8380 (559 characters)
# Chunk 440 processed: 100 words extracted
# Processing chunk 441/8380 (529 characters)
# Chunk 441 processed: 100 words extracted
# Processing chunk 442/8380 (520 characters)
# Chunk 442 processed: 100 words extracted
# Processing chunk 443/8380 (532 characters)
# Chunk 443 processed: 100 words extracted
# Processing chunk 444/8380 (564 characters)
# Chunk 444 processed: 100 words extracted
# Processing chunk 445/8380 (515 characters)
# Chunk 445 processed: 100 words extracted
# Processing chunk 446/8380 (537 characters)
# Chunk 446 processed: 100 words extracted
# Processing chunk 447/8380 (583 characters)
# Chunk 447 processed: 100 words extracted
# Processing chunk 448/8380 (553 characters)
# Chunk 448 processed: 100 words extracted
# Processing chunk 449/8380 (549 characters)
# Chunk 449 processed: 100 words extracted
# Processing chunk 450/8380 (541 characters)
# Chunk 450 processed: 100 words extracted
# Processing chunk 451/8380 (524 characters)
# Chunk 451 processed: 100 words extracted
# Processing chunk 452/8380 (514 characters)
# Chunk 452 processed: 100 words extracted
# Processing chunk 453/8380 (547 characters)
# Chunk 453 processed: 100 words extracted
# Processing chunk 454/8380 (521 characters)
# Chunk 454 processed: 100 words extracted
# Processing chunk 455/8380 (516 characters)
# Chunk 455 processed: 100 words extracted
# Processing chunk 456/8380 (497 characters)
# Chunk 456 processed: 100 words extracted
# Processing chunk 457/8380 (522 characters)
# Chunk 457 processed: 100 words extracted
# Processing chunk 458/8380 (536 characters)
# Chunk 458 processed: 100 words extracted
# Processing chunk 459/8380 (536 characters)
# Chunk 459 processed: 100 words extracted
# Processing chunk 460/8380 (570 characters)
# Chunk 460 processed: 100 words extracted
# Processing chunk 461/8380 (545 characters)
# Chunk 461 processed: 100 words extracted
# Processing chunk 462/8380 (556 characters)
# Chunk 462 processed: 100 words extracted
# Processing chunk 463/8380 (518 characters)
# Chunk 463 processed: 100 words extracted
# Processing chunk 464/8380 (516 characters)
# Chunk 464 processed: 100 words extracted
# Processing chunk 465/8380 (495 characters)
# Chunk 465 processed: 100 words extracted
# Processing chunk 466/8380 (511 characters)
# Chunk 466 processed: 100 words extracted
# Processing chunk 467/8380 (533 characters)
# Chunk 467 processed: 100 words extracted
# Processing chunk 468/8380 (515 characters)
# Chunk 468 processed: 100 words extracted
# Processing chunk 469/8380 (548 characters)
# Chunk 469 processed: 100 words extracted
# Processing chunk 470/8380 (531 characters)
# Chunk 470 processed: 101 words extracted
# Processing chunk 471/8380 (499 characters)
# Chunk 471 processed: 101 words extracted
# Processing chunk 472/8380 (561 characters)
# Chunk 472 processed: 100 words extracted
# Processing chunk 473/8380 (546 characters)
# Chunk 473 processed: 100 words extracted
# Processing chunk 474/8380 (539 characters)
# Chunk 474 processed: 100 words extracted
# Processing chunk 475/8380 (534 characters)
# Chunk 475 processed: 101 words extracted
# Processing chunk 476/8380 (524 characters)
# Chunk 476 processed: 100 words extracted
# Processing chunk 477/8380 (536 characters)
# Chunk 477 processed: 100 words extracted
# Processing chunk 478/8380 (526 characters)
# Chunk 478 processed: 100 words extracted
# Processing chunk 479/8380 (514 characters)
# Chunk 479 processed: 100 words extracted
# Processing chunk 480/8380 (519 characters)
# Chunk 480 processed: 100 words extracted
# Processing chunk 481/8380 (537 characters)
# Chunk 481 processed: 100 words extracted
# Processing chunk 482/8380 (513 characters)
# Chunk 482 processed: 100 words extracted
# Processing chunk 483/8380 (534 characters)
# Chunk 483 processed: 100 words extracted
# Processing chunk 484/8380 (493 characters)
# Chunk 484 processed: 104 words extracted
# Processing chunk 485/8380 (507 characters)
# Chunk 485 processed: 100 words extracted
# Processing chunk 486/8380 (487 characters)
# Chunk 486 processed: 100 words extracted
# Processing chunk 487/8380 (478 characters)
# Chunk 487 processed: 100 words extracted
# Processing chunk 488/8380 (511 characters)
# Chunk 488 processed: 101 words extracted
# Processing chunk 489/8380 (544 characters)
# Chunk 489 processed: 100 words extracted
# Processing chunk 490/8380 (515 characters)
# Chunk 490 processed: 100 words extracted
# Processing chunk 491/8380 (534 characters)
# Chunk 491 processed: 101 words extracted
# Processing chunk 492/8380 (523 characters)
# Chunk 492 processed: 101 words extracted
# Processing chunk 493/8380 (535 characters)
# Chunk 493 processed: 100 words extracted
# Processing chunk 494/8380 (538 characters)
# Chunk 494 processed: 100 words extracted
# Processing chunk 495/8380 (580 characters)
# Chunk 495 processed: 100 words extracted
# Processing chunk 496/8380 (512 characters)
# Chunk 496 processed: 100 words extracted
# Processing chunk 497/8380 (545 characters)
# Chunk 497 processed: 100 words extracted
# Processing chunk 498/8380 (540 characters)
# Chunk 498 processed: 100 words extracted
# Processing chunk 499/8380 (501 characters)
# Chunk 499 processed: 100 words extracted
# Processing chunk 500/8380 (525 characters)
# Chunk 500 processed: 100 words extracted
# Processing chunk 501/8380 (524 characters)
# Chunk 501 processed: 100 words extracted
# Processing chunk 502/8380 (532 characters)
# Chunk 502 processed: 100 words extracted
# Processing chunk 503/8380 (514 characters)
# Chunk 503 processed: 100 words extracted
# Processing chunk 504/8380 (533 characters)
# Chunk 504 processed: 100 words extracted
# Processing chunk 505/8380 (539 characters)
# Chunk 505 processed: 100 words extracted
# Processing chunk 506/8380 (522 characters)
# Chunk 506 processed: 100 words extracted
# Processing chunk 507/8380 (529 characters)
# Chunk 507 processed: 100 words extracted
# Processing chunk 508/8380 (500 characters)
# Chunk 508 processed: 101 words extracted
# Processing chunk 509/8380 (535 characters)
# Chunk 509 processed: 100 words extracted
# Processing chunk 510/8380 (551 characters)
# Chunk 510 processed: 100 words extracted
# Processing chunk 511/8380 (537 characters)
# Chunk 511 processed: 100 words extracted
# Processing chunk 512/8380 (534 characters)
# Chunk 512 processed: 100 words extracted
# Processing chunk 513/8380 (531 characters)
# Chunk 513 processed: 100 words extracted
# Processing chunk 514/8380 (537 characters)
# Chunk 514 processed: 100 words extracted
# Processing chunk 515/8380 (534 characters)
# Chunk 515 processed: 100 words extracted
# Processing chunk 516/8380 (557 characters)
# Chunk 516 processed: 100 words extracted
# Processing chunk 517/8380 (566 characters)
# Chunk 517 processed: 100 words extracted
# Processing chunk 518/8380 (502 characters)
# Chunk 518 processed: 100 words extracted
# Processing chunk 519/8380 (569 characters)
# Chunk 519 processed: 100 words extracted
# Processing chunk 520/8380 (533 characters)
# Chunk 520 processed: 101 words extracted
# Processing chunk 521/8380 (560 characters)
# Chunk 521 processed: 100 words extracted
# Processing chunk 522/8380 (525 characters)
# Chunk 522 processed: 100 words extracted
# Processing chunk 523/8380 (524 characters)
# Chunk 523 processed: 100 words extracted
# Processing chunk 524/8380 (518 characters)
# Chunk 524 processed: 100 words extracted
# Processing chunk 525/8380 (496 characters)
# Chunk 525 processed: 100 words extracted
# Processing chunk 526/8380 (562 characters)
# Chunk 526 processed: 100 words extracted
# Processing chunk 527/8380 (528 characters)
# Chunk 527 processed: 100 words extracted
# Processing chunk 528/8380 (511 characters)
# Chunk 528 processed: 100 words extracted
# Processing chunk 529/8380 (563 characters)
# Chunk 529 processed: 100 words extracted
# Processing chunk 530/8380 (521 characters)
# Chunk 530 processed: 100 words extracted
# Processing chunk 531/8380 (531 characters)
# Chunk 531 processed: 100 words extracted
# Processing chunk 532/8380 (547 characters)
# Chunk 532 processed: 100 words extracted
# Processing chunk 533/8380 (505 characters)
# Chunk 533 processed: 101 words extracted
# Processing chunk 534/8380 (546 characters)
# Chunk 534 processed: 100 words extracted
# Processing chunk 535/8380 (505 characters)
# Chunk 535 processed: 100 words extracted
# Processing chunk 536/8380 (551 characters)
# Chunk 536 processed: 100 words extracted
# Processing chunk 537/8380 (507 characters)
# Chunk 537 processed: 100 words extracted
# Processing chunk 538/8380 (525 characters)
# Chunk 538 processed: 100 words extracted
# Processing chunk 539/8380 (516 characters)
# Chunk 539 processed: 100 words extracted
# Processing chunk 540/8380 (536 characters)
# Chunk 540 processed: 100 words extracted
# Processing chunk 541/8380 (550 characters)
# Chunk 541 processed: 100 words extracted
# Processing chunk 542/8380 (552 characters)
# Chunk 542 processed: 100 words extracted
# Processing chunk 543/8380 (545 characters)
# Chunk 543 processed: 100 words extracted
# Processing chunk 544/8380 (508 characters)
# Chunk 544 processed: 100 words extracted
# Processing chunk 545/8380 (527 characters)
# Chunk 545 processed: 100 words extracted
# Processing chunk 546/8380 (575 characters)
# Chunk 546 processed: 100 words extracted
# Processing chunk 547/8380 (515 characters)
# Chunk 547 processed: 100 words extracted
# Processing chunk 548/8380 (534 characters)
# Chunk 548 processed: 100 words extracted
# Processing chunk 549/8380 (502 characters)
# Chunk 549 processed: 100 words extracted
# Processing chunk 550/8380 (534 characters)
# Chunk 550 processed: 100 words extracted
# Processing chunk 551/8380 (537 characters)
# Chunk 551 processed: 100 words extracted
# Processing chunk 552/8380 (525 characters)
# Chunk 552 processed: 100 words extracted
# Processing chunk 553/8380 (558 characters)
# Chunk 553 processed: 100 words extracted
# Processing chunk 554/8380 (516 characters)
# Chunk 554 processed: 100 words extracted
# Processing chunk 555/8380 (534 characters)
# Chunk 555 processed: 100 words extracted
# Processing chunk 556/8380 (500 characters)
# Chunk 556 processed: 100 words extracted
# Processing chunk 557/8380 (517 characters)
# Chunk 557 processed: 100 words extracted
# Processing chunk 558/8380 (531 characters)
# Chunk 558 processed: 100 words extracted
# Processing chunk 559/8380 (531 characters)
# Chunk 559 processed: 100 words extracted
# Processing chunk 560/8380 (536 characters)
# Chunk 560 processed: 100 words extracted
# Processing chunk 561/8380 (561 characters)
# Chunk 561 processed: 100 words extracted
# Processing chunk 562/8380 (565 characters)
# Chunk 562 processed: 100 words extracted
# Processing chunk 563/8380 (555 characters)
# Chunk 563 processed: 100 words extracted
# Processing chunk 564/8380 (524 characters)
# Chunk 564 processed: 100 words extracted
# Processing chunk 565/8380 (547 characters)
# Chunk 565 processed: 100 words extracted
# Processing chunk 566/8380 (503 characters)
# Chunk 566 processed: 100 words extracted
# Processing chunk 567/8380 (435 characters)
# Chunk 567 processed: 100 words extracted
# Processing chunk 568/8380 (506 characters)
# Chunk 568 processed: 100 words extracted
# Processing chunk 569/8380 (516 characters)
# Chunk 569 processed: 100 words extracted
# Processing chunk 570/8380 (499 characters)
# Chunk 570 processed: 100 words extracted
# ...
# Processing chunk 8200/8380 (528 characters)
# Chunk 8200 processed: 100 words extracted
# Processing chunk 8201/8380 (553 characters)
# Chunk 8201 processed: 100 words extracted
# Processing chunk 8202/8380 (551 characters)
# Chunk 8202 processed: 100 words extracted
# Processing chunk 8203/8380 (568 characters)
# Chunk 8203 processed: 100 words extracted
# Processing chunk 8204/8380 (545 characters)
# Chunk 8204 processed: 100 words extracted
# Processing chunk 8205/8380 (561 characters)
# Chunk 8205 processed: 100 words extracted
# Processing chunk 8206/8380 (548 characters)
# Chunk 8206 processed: 100 words extracted
# Processing chunk 8207/8380 (579 characters)
# Chunk 8207 processed: 100 words extracted
# Processing chunk 8208/8380 (537 characters)
# Chunk 8208 processed: 100 words extracted
# Processing chunk 8209/8380 (602 characters)
# Chunk 8209 processed: 100 words extracted
# Processing chunk 8210/8380 (565 characters)
# Chunk 8210 processed: 100 words extracted
# Processing chunk 8211/8380 (556 characters)
# Chunk 8211 processed: 100 words extracted
# Processing chunk 8212/8380 (579 characters)
# Chunk 8212 processed: 100 words extracted
# Processing chunk 8213/8380 (543 characters)
# Chunk 8213 processed: 100 words extracted
# Processing chunk 8214/8380 (526 characters)
# Chunk 8214 processed: 100 words extracted
# Processing chunk 8215/8380 (537 characters)
# Chunk 8215 processed: 100 words extracted
# Processing chunk 8216/8380 (582 characters)
# Chunk 8216 processed: 100 words extracted
# Processing chunk 8217/8380 (527 characters)
# Chunk 8217 processed: 100 words extracted
# Processing chunk 8218/8380 (568 characters)
# Chunk 8218 processed: 100 words extracted
# Processing chunk 8219/8380 (568 characters)
# Chunk 8219 processed: 100 words extracted
# Processing chunk 8220/8380 (561 characters)
# Chunk 8220 processed: 100 words extracted
# Processing chunk 8221/8380 (551 characters)
# Chunk 8221 processed: 100 words extracted
# Processing chunk 8222/8380 (542 characters)
# Chunk 8222 processed: 100 words extracted
# Processing chunk 8223/8380 (518 characters)
# Chunk 8223 processed: 100 words extracted
# Processing chunk 8224/8380 (581 characters)
# Chunk 8224 processed: 100 words extracted
# Processing chunk 8225/8380 (564 characters)
# Chunk 8225 processed: 100 words extracted
# Processing chunk 8226/8380 (517 characters)
# Chunk 8226 processed: 100 words extracted
# Processing chunk 8227/8380 (569 characters)
# Chunk 8227 processed: 100 words extracted
# Processing chunk 8228/8380 (540 characters)
# Chunk 8228 processed: 101 words extracted
# Processing chunk 8229/8380 (533 characters)
# Chunk 8229 processed: 100 words extracted
# Processing chunk 8230/8380 (544 characters)
# Chunk 8230 processed: 100 words extracted
# Processing chunk 8231/8380 (538 characters)
# Chunk 8231 processed: 100 words extracted
# Processing chunk 8232/8380 (558 characters)
# Chunk 8232 processed: 100 words extracted
# Processing chunk 8233/8380 (540 characters)
# Chunk 8233 processed: 100 words extracted
# Processing chunk 8234/8380 (549 characters)
# Chunk 8234 processed: 100 words extracted
# Processing chunk 8235/8380 (527 characters)
# Chunk 8235 processed: 100 words extracted
# Processing chunk 8236/8380 (532 characters)
# Chunk 8236 processed: 100 words extracted
# Processing chunk 8237/8380 (547 characters)
# Chunk 8237 processed: 100 words extracted
# Processing chunk 8238/8380 (571 characters)
# Chunk 8238 processed: 100 words extracted
# Processing chunk 8239/8380 (546 characters)
# Chunk 8239 processed: 100 words extracted
# Processing chunk 8240/8380 (546 characters)
# Chunk 8240 processed: 100 words extracted
# Processing chunk 8241/8380 (571 characters)
# Chunk 8241 processed: 100 words extracted
# Processing chunk 8242/8380 (552 characters)
# Chunk 8242 processed: 101 words extracted
# Processing chunk 8243/8380 (536 characters)
# Chunk 8243 processed: 100 words extracted
# Processing chunk 8244/8380 (571 characters)
# Chunk 8244 processed: 100 words extracted
# Processing chunk 8245/8380 (566 characters)
# Chunk 8245 processed: 101 words extracted
# Processing chunk 8246/8380 (557 characters)
# Chunk 8246 processed: 100 words extracted
# Processing chunk 8247/8380 (559 characters)
# Chunk 8247 processed: 100 words extracted
# Processing chunk 8248/8380 (565 characters)
# Chunk 8248 processed: 100 words extracted
# Processing chunk 8249/8380 (552 characters)
# Chunk 8249 processed: 100 words extracted
# Processing chunk 8250/8380 (516 characters)
# Chunk 8250 processed: 100 words extracted
# Processing chunk 8251/8380 (537 characters)
# Chunk 8251 processed: 100 words extracted
# Processing chunk 8252/8380 (545 characters)
# Chunk 8252 processed: 100 words extracted
# Processing chunk 8253/8380 (585 characters)
# Chunk 8253 processed: 100 words extracted
# Processing chunk 8254/8380 (542 characters)
# Chunk 8254 processed: 101 words extracted
# Processing chunk 8255/8380 (579 characters)
# Chunk 8255 processed: 100 words extracted
# Processing chunk 8256/8380 (563 characters)
# Chunk 8256 processed: 100 words extracted
# Processing chunk 8257/8380 (559 characters)
# Chunk 8257 processed: 100 words extracted
# Processing chunk 8258/8380 (506 characters)
# Chunk 8258 processed: 100 words extracted
# Processing chunk 8259/8380 (547 characters)
# Chunk 8259 processed: 100 words extracted
# Processing chunk 8260/8380 (566 characters)
# Chunk 8260 processed: 100 words extracted
# Processing chunk 8261/8380 (545 characters)
# Chunk 8261 processed: 100 words extracted
# Processing chunk 8262/8380 (539 characters)
# Chunk 8262 processed: 100 words extracted
# Processing chunk 8263/8380 (549 characters)
# Chunk 8263 processed: 100 words extracted
# Processing chunk 8264/8380 (528 characters)
# Chunk 8264 processed: 100 words extracted
# Processing chunk 8265/8380 (544 characters)
# Chunk 8265 processed: 100 words extracted
# Processing chunk 8266/8380 (551 characters)
# Chunk 8266 processed: 100 words extracted
# Processing chunk 8267/8380 (560 characters)
# Chunk 8267 processed: 100 words extracted
# Processing chunk 8268/8380 (562 characters)
# Chunk 8268 processed: 100 words extracted
# Processing chunk 8269/8380 (558 characters)
# Chunk 8269 processed: 100 words extracted
# Processing chunk 8270/8380 (513 characters)
# Chunk 8270 processed: 100 words extracted
# Processing chunk 8271/8380 (550 characters)
# Chunk 8271 processed: 100 words extracted
# Processing chunk 8272/8380 (525 characters)
# Chunk 8272 processed: 100 words extracted
# Processing chunk 8273/8380 (565 characters)
# Chunk 8273 processed: 100 words extracted
# Processing chunk 8274/8380 (531 characters)
# Chunk 8274 processed: 100 words extracted
# Processing chunk 8275/8380 (540 characters)
# Chunk 8275 processed: 100 words extracted
# Processing chunk 8276/8380 (541 characters)
# Chunk 8276 processed: 100 words extracted
# Processing chunk 8277/8380 (550 characters)
# Chunk 8277 processed: 100 words extracted
# Processing chunk 8278/8380 (560 characters)
# Chunk 8278 processed: 100 words extracted
# Processing chunk 8279/8380 (568 characters)
# Chunk 8279 processed: 100 words extracted
# Processing chunk 8280/8380 (573 characters)
# Chunk 8280 processed: 100 words extracted
# Processing chunk 8281/8380 (536 characters)
# Chunk 8281 processed: 100 words extracted
# Processing chunk 8282/8380 (574 characters)
# Chunk 8282 processed: 100 words extracted
# Processing chunk 8283/8380 (547 characters)
# Chunk 8283 processed: 100 words extracted
# Processing chunk 8284/8380 (561 characters)
# Chunk 8284 processed: 100 words extracted
# Processing chunk 8285/8380 (552 characters)
# Chunk 8285 processed: 100 words extracted
# Processing chunk 8286/8380 (535 characters)
# Chunk 8286 processed: 100 words extracted
# Processing chunk 8287/8380 (546 characters)
# Chunk 8287 processed: 100 words extracted
# Processing chunk 8288/8380 (562 characters)
# Chunk 8288 processed: 100 words extracted
# Processing chunk 8289/8380 (553 characters)
# Chunk 8289 processed: 100 words extracted
# Processing chunk 8290/8380 (555 characters)
# Chunk 8290 processed: 100 words extracted
# Processing chunk 8291/8380 (524 characters)
# Chunk 8291 processed: 101 words extracted
# Processing chunk 8292/8380 (484 characters)
# Chunk 8292 processed: 101 words extracted
# Processing chunk 8293/8380 (541 characters)
# Chunk 8293 processed: 100 words extracted
# Processing chunk 8294/8380 (544 characters)
# Chunk 8294 processed: 100 words extracted
# Processing chunk 8295/8380 (524 characters)
# Chunk 8295 processed: 100 words extracted
# Processing chunk 8296/8380 (543 characters)
# Chunk 8296 processed: 100 words extracted
# Processing chunk 8297/8380 (545 characters)
# Chunk 8297 processed: 100 words extracted
# Processing chunk 8298/8380 (543 characters)
# Chunk 8298 processed: 100 words extracted
# Processing chunk 8299/8380 (569 characters)
# Chunk 8299 processed: 101 words extracted
# Processing chunk 8300/8380 (550 characters)
# Chunk 8300 processed: 100 words extracted
# Processing chunk 8301/8380 (495 characters)
# Chunk 8301 processed: 100 words extracted
# Processing chunk 8302/8380 (538 characters)
# Chunk 8302 processed: 100 words extracted
# Processing chunk 8303/8380 (551 characters)
# Chunk 8303 processed: 100 words extracted
# Processing chunk 8304/8380 (585 characters)
# Chunk 8304 processed: 100 words extracted
# Processing chunk 8305/8380 (542 characters)
# Chunk 8305 processed: 100 words extracted
# Processing chunk 8306/8380 (579 characters)
# Chunk 8306 processed: 100 words extracted
# Processing chunk 8307/8380 (563 characters)
# Chunk 8307 processed: 100 words extracted
# Processing chunk 8308/8380 (576 characters)
# Chunk 8308 processed: 100 words extracted
# Processing chunk 8309/8380 (567 characters)
# Chunk 8309 processed: 100 words extracted
# Processing chunk 8310/8380 (564 characters)
# Chunk 8310 processed: 100 words extracted
# Processing chunk 8311/8380 (567 characters)
# Chunk 8311 processed: 100 words extracted
# Processing chunk 8312/8380 (556 characters)
# Chunk 8312 processed: 100 words extracted
# Processing chunk 8313/8380 (555 characters)
# Chunk 8313 processed: 100 words extracted
# Processing chunk 8314/8380 (540 characters)
# Chunk 8314 processed: 100 words extracted
# Processing chunk 8315/8380 (538 characters)
# Chunk 8315 processed: 100 words extracted
# Processing chunk 8316/8380 (522 characters)
# Chunk 8316 processed: 100 words extracted
# Processing chunk 8317/8380 (560 characters)
# Chunk 8317 processed: 100 words extracted
# Processing chunk 8318/8380 (554 characters)
# Chunk 8318 processed: 100 words extracted
# Processing chunk 8319/8380 (566 characters)
# Chunk 8319 processed: 100 words extracted
# Processing chunk 8320/8380 (569 characters)
# Chunk 8320 processed: 100 words extracted
# Processing chunk 8321/8380 (549 characters)
# Chunk 8321 processed: 100 words extracted
# Processing chunk 8322/8380 (536 characters)
# Chunk 8322 processed: 100 words extracted
# Processing chunk 8323/8380 (596 characters)
# Chunk 8323 processed: 101 words extracted
# Processing chunk 8324/8380 (523 characters)
# Chunk 8324 processed: 100 words extracted
# Processing chunk 8325/8380 (544 characters)
# Chunk 8325 processed: 100 words extracted
# Processing chunk 8326/8380 (553 characters)
# Chunk 8326 processed: 100 words extracted
# Processing chunk 8327/8380 (481 characters)
# Chunk 8327 processed: 100 words extracted
# Processing chunk 8328/8380 (539 characters)
# Chunk 8328 processed: 100 words extracted
# Processing chunk 8329/8380 (561 characters)
# Chunk 8329 processed: 100 words extracted
# Processing chunk 8330/8380 (535 characters)
# Chunk 8330 processed: 100 words extracted
# Processing chunk 8331/8380 (562 characters)
# Chunk 8331 processed: 100 words extracted
# Processing chunk 8332/8380 (549 characters)
# Chunk 8332 processed: 100 words extracted
# Processing chunk 8333/8380 (543 characters)
# Chunk 8333 processed: 100 words extracted
# Processing chunk 8334/8380 (556 characters)
# Chunk 8334 processed: 100 words extracted
# Processing chunk 8335/8380 (578 characters)
# Chunk 8335 processed: 100 words extracted
# Processing chunk 8336/8380 (561 characters)
# Chunk 8336 processed: 100 words extracted
# Processing chunk 8337/8380 (527 characters)
# Chunk 8337 processed: 100 words extracted
# Processing chunk 8338/8380 (552 characters)
# Chunk 8338 processed: 100 words extracted
# Processing chunk 8339/8380 (565 characters)
# Chunk 8339 processed: 100 words extracted
# Processing chunk 8340/8380 (557 characters)
# Chunk 8340 processed: 100 words extracted
# Processing chunk 8341/8380 (539 characters)
# Chunk 8341 processed: 100 words extracted
# Processing chunk 8342/8380 (554 characters)
# Chunk 8342 processed: 100 words extracted
# Processing chunk 8343/8380 (556 characters)
# Chunk 8343 processed: 100 words extracted
# Processing chunk 8344/8380 (536 characters)
# Chunk 8344 processed: 100 words extracted
# Processing chunk 8345/8380 (596 characters)
# Chunk 8345 processed: 100 words extracted
# Processing chunk 8346/8380 (527 characters)
# Chunk 8346 processed: 100 words extracted
# Processing chunk 8347/8380 (574 characters)
# Chunk 8347 processed: 100 words extracted
# Processing chunk 8348/8380 (587 characters)
# Chunk 8348 processed: 100 words extracted
# Processing chunk 8349/8380 (557 characters)
# Chunk 8349 processed: 100 words extracted
# Processing chunk 8350/8380 (555 characters)
# Chunk 8350 processed: 100 words extracted
# Processing chunk 8351/8380 (576 characters)
# Chunk 8351 processed: 100 words extracted
# Processing chunk 8352/8380 (547 characters)
# Chunk 8352 processed: 100 words extracted
# Processing chunk 8353/8380 (574 characters)
# Chunk 8353 processed: 100 words extracted
# Processing chunk 8354/8380 (560 characters)
# Chunk 8354 processed: 100 words extracted
# Processing chunk 8355/8380 (540 characters)
# Chunk 8355 processed: 101 words extracted
# Processing chunk 8356/8380 (572 characters)
# Chunk 8356 processed: 100 words extracted
# Processing chunk 8357/8380 (526 characters)
# Chunk 8357 processed: 100 words extracted
# Processing chunk 8358/8380 (526 characters)
# Chunk 8358 processed: 100 words extracted
# Processing chunk 8359/8380 (562 characters)
# Chunk 8359 processed: 100 words extracted
# Processing chunk 8360/8380 (587 characters)
# Chunk 8360 processed: 100 words extracted
# Processing chunk 8361/8380 (558 characters)
# Chunk 8361 processed: 100 words extracted
# Processing chunk 8362/8380 (563 characters)
# Chunk 8362 processed: 100 words extracted
# Processing chunk 8363/8380 (530 characters)
# Chunk 8363 processed: 100 words extracted
# Processing chunk 8364/8380 (556 characters)
# Chunk 8364 processed: 100 words extracted
# Processing chunk 8365/8380 (513 characters)
# Chunk 8365 processed: 100 words extracted
# Processing chunk 8366/8380 (550 characters)
# Chunk 8366 processed: 101 words extracted
# Processing chunk 8367/8380 (538 characters)
# Chunk 8367 processed: 100 words extracted
# Processing chunk 8368/8380 (555 characters)
# Chunk 8368 processed: 100 words extracted
# Processing chunk 8369/8380 (537 characters)
# Chunk 8369 processed: 100 words extracted
# Processing chunk 8370/8380 (545 characters)
# Chunk 8370 processed: 100 words extracted
# Processing chunk 8371/8380 (554 characters)
# Chunk 8371 processed: 100 words extracted
# Processing chunk 8372/8380 (560 characters)
# Chunk 8372 processed: 100 words extracted
# Processing chunk 8373/8380 (541 characters)
# Chunk 8373 processed: 100 words extracted
# Processing chunk 8374/8380 (556 characters)
# Chunk 8374 processed: 100 words extracted
# Processing chunk 8375/8380 (547 characters)
# Chunk 8375 processed: 100 words extracted
# Processing chunk 8376/8380 (569 characters)
# Chunk 8376 processed: 100 words extracted
# Processing chunk 8377/8380 (537 characters)
# Chunk 8377 processed: 100 words extracted
# Processing chunk 8378/8380 (555 characters)
# Chunk 8378 processed: 100 words extracted
# Processing chunk 8379/8380 (556 characters)
# Chunk 8379 processed: 100 words extracted
# Processing chunk 8380/8380 (33 characters)
# Chunk 8380 processed: 8 words extracted
# Processing completed:
#   ✅ Successful chunks: 8380
#   ❌ Failed chunks: 0
#   📊 Total words extracted: 838360
#
# Step 4: Saving POS tagging results...
# POS results saved to pos_output.csv
#
# === Summary ===
# ✅ Text processed: 4512997 characters
# ✅ Words analyzed: 838360
# ✅ Output files created:
#    - pos_output.csv (POS tagging results)
#    - banking_entities.csv (Banking entities)
#    - banking_entities.xlsx (Banking entities - Excel)
